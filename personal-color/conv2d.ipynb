# %%
import os
import PIL
import dlib
# import matplotlib.pyplot as plt
import datetime
import numpy as np

from sklearn.metrics import confusion_matrix
# import seaborn as sns
import pandas as pd

# %%
import torch
import torchvision.transforms as transforms
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split, SubsetRandomSampler
import torch.optim as optim

import tensorboardX

# %%
torch.manual_seed(0)
np.random.seed(0)

# %%
epochs = 50
batch_size = 16
lr = 1e-4

# %%
logname = f'conv2d_{batch_size}_{epochs}_{lr}_{datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")}'

if not os.path.exists(os.path.join('models', logname)):
    os.makedirs(os.path.join('models', logname))

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# %%
data_root = 'images/dataset'
save_path = 'images/cropped_faces'

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class FaceDataset(Dataset):
    def __init__(self, n_classes=4, root_dir=save_path, transform=transform):
        self.root_dir = root_dir
        self.transform = transform
        self.files = os.listdir(self.root_dir)
        # self.labels = [int(file.split('_')[0]) for file in self.files]
        
        self.n_classes = n_classes
        
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.files[idx])
        img = PIL.Image.open(img_name)
        img = self.transform(img)
        label = int(self.files[idx].split('_')[0])
        label = label if self.n_classes == 4 else label // 2
        return img, label

# %%
dataset = FaceDataset(n_classes=4)
train_data = dataset

# len_data = len(dataset)
# train_size = int(0.8 * len_data)
# test_size = len_data - train_size

# train_data, test_data = random_split(dataset, [train_size, test_size])
# test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# print('Train:', len(train_data), 'Test:', len(test_data))

# %%
class Model(nn.Module):
    def __init__(self, n_classes):
        super(Model, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=1, padding=0)
        self.conv3 = nn.Conv2d(32, 16, kernel_size=3, stride=1, padding=1)
        self.maxpool = nn.MaxPool2d(kernel_size=2)
        self.fc1 = nn.Linear(16 * 15 * 15, n_classes)
        self.dropout1 = nn.Dropout(0.4)
        self.dropout2 = nn.Dropout(0.4)
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)
        # (input - f + 2p) / s + 1
    def forward(self, x):
        x = self.relu(self.conv1(x))  # (256 - 5 + 1) / 2 + 1 = 128  [16, 128, 128]
        x = self.maxpool(x)  # [16, 64, 64]
        x = self.relu(self.conv2(x))  # (64 - 5) + 1 = 60 [32, 60, 60]
        x = self.maxpool(x)  # [32, 30, 30]
        x = self.relu(self.conv3(x))  # [16, 30, 30]
        x = self.maxpool(x)  # [16, 15, 15]
        x = self.dropout1(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.dropout2(x)
        x = self.softmax(x)
        return x

# %%
writer = tensorboardX.SummaryWriter(logdir=f'runs/{logname}'+ datetime.datetime.now().strftime('%Y%m%d%H%M%S'))

# %%
def train(model, train_loader, optimizer, criterion, epoch):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for i, (inputs, labels) in enumerate(train_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        
        writer.add_scalar('train_loss', loss.item(), i*epoch)
        writer.add_scalar('train_accuracy', 100*correct/total, i*epoch)
        
        if i % 10 == 99:
            print(f'[{i+1}, {running_loss/100:.3f}]')
            running_loss = 0.0
            correct = 0
            total = 0
        
    train_loss = running_loss/len(train_loader)
    train_accuracy = 100*correct/total
    print(f'Training {epoch+1}/{epochs}:\tTrain loss: {train_loss:.3f},\tTrain acc: {train_accuracy:.3f}')
    
    return train_loss, train_accuracy

# %%
y_pred = []
y_true = []
    
def test(model, test_loader, criterion):
    model.eval()
    
    total_loss = 0
    
    with torch.no_grad():
        
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            
            y_pred.extend(predicted.cpu().numpy())
            y_true.extend(labels.cpu().numpy())
            
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            
    test_loss = total_loss / len(test_loader)
    test_acc = 100 * sum([1 for i in range(len(y_pred)) if y_pred[i] == y_true[i]]) / len(y_true)
    print(f'Test:\tTest loss: {test_loss:.3f},\tTest acc: {test_acc:.3f}')
    
    writer.add_scalar('test_accuracy', test_acc)
    writer.add_scalar('test_loss', test_loss)
    
    return test_loss, test_acc

# %%
# def train_val_curve(epoch, fold, train_losses, train_accuracies, val_losses, val_accuracies):
#     fig, ax = plt.subplots(2, 1, figsize=(10, 10))
    
#     ax[0].plot(range(epochs*fold), train_losses, label='train')
#     ax[0].plot(range(epochs*fold), val_losses, label='val')
#     ax[0].set_title('Loss')
#     ax[0].legend()
    
#     ax[1].plot(range(epochs*fold), train_accuracies, label='train')
#     ax[1].plot(range(epochs*fold), val_accuracies, label='val')
#     ax[1].set_title('Accuracy')
#     ax[1].legend()
    
#     plt.show()
    
#     writer.add_figure('train_val_curve', fig, epoch*fold)

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=5, shuffle=True, random_state=0)

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        torch.nn.init.xavier_uniform(m.weight.data)

# %%
train_losses_folds, train_accs_folds = [], []
test_losses_folds, test_accs_folds = [], []

# %%
def run():
    for fold, (train_idx, test_idx) in enumerate(kfold.split(train_data)):
        print(f'Fold {fold+1}/{5}')
        
        train_subset = SubsetRandomSampler(train_idx)
        test_subset = SubsetRandomSampler(test_idx)
        train_loader = DataLoader(train_data, batch_size=batch_size, sampler=train_subset)
        test_loader = DataLoader(train_data, batch_size=batch_size, sampler=test_subset)
        
        model = Model(dataset.n_classes).to(device)
        model.apply(weights_init)
        
        optimizer = optim.Adam(model.parameters(), lr=lr)
        criterion = nn.CrossEntropyLoss()
        
        train_losses = []
        train_accuracies = []
        
        for epoch in range(epochs):
            
            train_loss, train_acc = train(model, train_loader, optimizer, criterion, epoch)
            
            train_losses.append(train_loss)
            train_accuracies.append(train_acc)
            
        train_losses_folds.append(sum(train_losses) / len(train_losses))
        train_accs_folds.append(sum(train_accuracies) / len(train_accuracies))
        print(f'Train {fold+1}/{5}:\tTrain loss: {train_losses_folds[-1]:.3f},\tTrain acc: {train_accs_folds[-1]:.3f}')
        
        test_loss, test_acc = test(model, test_loader, criterion)
        print(f'Test {fold+1}/{5}:\tTest loss: {test_loss:.3f},\tTest acc: {test_acc:.3f}')
        
        test_losses_folds.append(test_loss)
        test_accs_folds.append(test_acc)
                
    final_train_loss = sum(train_losses_folds) / len(train_losses_folds)
    final_train_acc = sum(train_accs_folds) / len(train_accs_folds)
    
    final_test_loss = sum(test_losses_folds) / len(test_losses_folds)
    final_test_acc = sum(test_accs_folds) / len(test_accs_folds)
    
    return final_train_loss, final_train_acc, final_test_loss, final_test_acc

# %%
train_loss, train_acc, train_loss, train_acc = run()
# Out:
# Fold 1/5
# C:\Users\pomat\AppData\Local\Temp\ipykernel_64424\1855755017.py:3: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   torch.nn.init.xavier_uniform(m.weight.data)
# Training 1/100:	Train loss: 1.369,	Train acc: 32.605
# Training 2/100:	Train loss: 1.355,	Train acc: 35.157
# Training 3/100:	Train loss: 1.338,	Train acc: 37.267
# Training 4/100:	Train loss: 1.326,	Train acc: 38.199
# Training 5/100:	Train loss: 1.312,	Train acc: 40.088
# Training 6/100:	Train loss: 1.307,	Train acc: 40.677
# Training 7/100:	Train loss: 1.293,	Train acc: 42.174
# Training 8/100:	Train loss: 1.278,	Train acc: 44.112
# Training 9/100:	Train loss: 1.272,	Train acc: 45.461
# Training 10/100:	Train loss: 1.263,	Train acc: 46.246
# Training 11/100:	Train loss: 1.253,	Train acc: 47.792
# Training 12/100:	Train loss: 1.247,	Train acc: 48.307
# Training 13/100:	Train loss: 1.244,	Train acc: 48.577
# Training 14/100:	Train loss: 1.240,	Train acc: 49.117
# Training 15/100:	Train loss: 1.227,	Train acc: 49.828
# Training 16/100:	Train loss: 1.225,	Train acc: 50.466
# Training 17/100:	Train loss: 1.226,	Train acc: 50.074
# Training 18/100:	Train loss: 1.223,	Train acc: 50.638
# Training 19/100:	Train loss: 1.220,	Train acc: 51.472
# Training 20/100:	Train loss: 1.218,	Train acc: 51.325
# Training 21/100:	Train loss: 1.208,	Train acc: 52.944
# Training 22/100:	Train loss: 1.205,	Train acc: 52.380
# Training 23/100:	Train loss: 1.207,	Train acc: 52.380
# Training 24/100:	Train loss: 1.209,	Train acc: 52.355
# Training 25/100:	Train loss: 1.205,	Train acc: 52.159
# Training 26/100:	Train loss: 1.202,	Train acc: 52.331
# Training 27/100:	Train loss: 1.200,	Train acc: 52.429
# Training 28/100:	Train loss: 1.197,	Train acc: 53.582
# Training 29/100:	Train loss: 1.200,	Train acc: 53.827
# Training 30/100:	Train loss: 1.191,	Train acc: 53.901
# Training 31/100:	Train loss: 1.191,	Train acc: 53.533
# Training 32/100:	Train loss: 1.193,	Train acc: 54.220
# Training 33/100:	Train loss: 1.182,	Train acc: 54.686
# Training 34/100:	Train loss: 1.184,	Train acc: 55.250
# Training 35/100:	Train loss: 1.180,	Train acc: 55.250
# Training 36/100:	Train loss: 1.184,	Train acc: 54.490
# Training 37/100:	Train loss: 1.179,	Train acc: 55.299
# Training 38/100:	Train loss: 1.175,	Train acc: 55.299
# Training 39/100:	Train loss: 1.167,	Train acc: 56.281
# Training 40/100:	Train loss: 1.175,	Train acc: 55.790
# Training 41/100:	Train loss: 1.176,	Train acc: 55.692
# Training 42/100:	Train loss: 1.168,	Train acc: 56.084
# Training 43/100:	Train loss: 1.172,	Train acc: 55.226
# Training 44/100:	Train loss: 1.173,	Train acc: 55.986
# Training 45/100:	Train loss: 1.165,	Train acc: 56.968
# Training 46/100:	Train loss: 1.166,	Train acc: 56.673
# Training 47/100:	Train loss: 1.165,	Train acc: 56.968
# Training 48/100:	Train loss: 1.169,	Train acc: 55.888
# Training 49/100:	Train loss: 1.160,	Train acc: 56.624
# Training 50/100:	Train loss: 1.163,	Train acc: 56.820
# Training 51/100:	Train loss: 1.153,	Train acc: 57.924
# Training 52/100:	Train loss: 1.161,	Train acc: 56.943
# Training 53/100:	Train loss: 1.172,	Train acc: 56.256
# Training 54/100:	Train loss: 1.154,	Train acc: 57.581
# Training 55/100:	Train loss: 1.155,	Train acc: 57.924
# Training 56/100:	Train loss: 1.145,	Train acc: 58.906
# Training 57/100:	Train loss: 1.152,	Train acc: 58.072
# Training 58/100:	Train loss: 1.145,	Train acc: 58.440
# Training 59/100:	Train loss: 1.150,	Train acc: 58.464
# Training 60/100:	Train loss: 1.145,	Train acc: 59.470
# Training 61/100:	Train loss: 1.146,	Train acc: 58.881
# Training 62/100:	Train loss: 1.143,	Train acc: 59.225
# Training 63/100:	Train loss: 1.143,	Train acc: 59.298
# Training 64/100:	Train loss: 1.137,	Train acc: 59.544
# Training 65/100:	Train loss: 1.145,	Train acc: 58.342
# Training 66/100:	Train loss: 1.142,	Train acc: 59.347
# Training 67/100:	Train loss: 1.135,	Train acc: 59.593
# Training 68/100:	Train loss: 1.148,	Train acc: 59.127
# Training 69/100:	Train loss: 1.131,	Train acc: 60.402
# Training 70/100:	Train loss: 1.140,	Train acc: 59.715
# Training 71/100:	Train loss: 1.131,	Train acc: 60.182
# Training 72/100:	Train loss: 1.139,	Train acc: 59.249
# Training 73/100:	Train loss: 1.131,	Train acc: 60.206
# Training 74/100:	Train loss: 1.133,	Train acc: 60.721
# Training 75/100:	Train loss: 1.130,	Train acc: 61.187
# Training 76/100:	Train loss: 1.132,	Train acc: 60.378
# Training 77/100:	Train loss: 1.131,	Train acc: 60.942
# Training 78/100:	Train loss: 1.129,	Train acc: 61.114
# Training 79/100:	Train loss: 1.127,	Train acc: 60.721
# Training 80/100:	Train loss: 1.135,	Train acc: 60.255
# Training 81/100:	Train loss: 1.132,	Train acc: 60.648
# Training 82/100:	Train loss: 1.120,	Train acc: 61.335
# Training 83/100:	Train loss: 1.126,	Train acc: 60.182
# Training 84/100:	Train loss: 1.120,	Train acc: 61.359
# Training 85/100:	Train loss: 1.123,	Train acc: 61.482
# Training 86/100:	Train loss: 1.120,	Train acc: 61.384
# Training 87/100:	Train loss: 1.126,	Train acc: 60.795
# Training 88/100:	Train loss: 1.119,	Train acc: 60.893
# Training 89/100:	Train loss: 1.120,	Train acc: 61.727
# Training 90/100:	Train loss: 1.119,	Train acc: 61.089
# Training 91/100:	Train loss: 1.116,	Train acc: 62.586
# Training 92/100:	Train loss: 1.120,	Train acc: 61.114
# Training 93/100:	Train loss: 1.124,	Train acc: 60.967
# Training 94/100:	Train loss: 1.109,	Train acc: 62.929
# Training 95/100:	Train loss: 1.109,	Train acc: 62.709
# Training 96/100:	Train loss: 1.113,	Train acc: 62.439
# Training 97/100:	Train loss: 1.112,	Train acc: 62.561
# Training 98/100:	Train loss: 1.104,	Train acc: 63.592
# Training 99/100:	Train loss: 1.113,	Train acc: 62.807
# Training 100/100:	Train loss: 1.109,	Train acc: 63.003
# Train 1/5:	Train loss: 1.176,	Train acc: 55.549
# Test:	Test loss: 1.126,	Test acc: 60.490
# Test 1/5:	Test loss: 1.126,	Test acc: 60.490
# Fold 2/5
# Training 1/100:	Train loss: 1.368,	Train acc: 34.045
# Training 2/100:	Train loss: 1.342,	Train acc: 37.258
# Training 3/100:	Train loss: 1.331,	Train acc: 37.846
# Training 4/100:	Train loss: 1.325,	Train acc: 39.220
# Training 5/100:	Train loss: 1.313,	Train acc: 40.863
# Training 6/100:	Train loss: 1.297,	Train acc: 42.065
# Training 7/100:	Train loss: 1.287,	Train acc: 43.071
# Training 8/100:	Train loss: 1.280,	Train acc: 43.684
# Training 9/100:	Train loss: 1.273,	Train acc: 45.156
# Training 10/100:	Train loss: 1.259,	Train acc: 46.676
# Training 11/100:	Train loss: 1.255,	Train acc: 47.805
# Training 12/100:	Train loss: 1.243,	Train acc: 48.246
# Training 13/100:	Train loss: 1.250,	Train acc: 47.903
# Training 14/100:	Train loss: 1.241,	Train acc: 48.197
# Training 15/100:	Train loss: 1.235,	Train acc: 49.571
# Training 16/100:	Train loss: 1.232,	Train acc: 49.276
# Training 17/100:	Train loss: 1.226,	Train acc: 49.007
# Training 18/100:	Train loss: 1.227,	Train acc: 50.159
# Training 19/100:	Train loss: 1.221,	Train acc: 50.773
# Training 20/100:	Train loss: 1.222,	Train acc: 50.331
# Training 21/100:	Train loss: 1.215,	Train acc: 52.146
# Training 22/100:	Train loss: 1.208,	Train acc: 52.220
# Training 23/100:	Train loss: 1.213,	Train acc: 51.631
# Training 24/100:	Train loss: 1.212,	Train acc: 52.171
# Training 25/100:	Train loss: 1.210,	Train acc: 52.048
# Training 26/100:	Train loss: 1.202,	Train acc: 52.514
# Training 27/100:	Train loss: 1.194,	Train acc: 54.035
# Training 28/100:	Train loss: 1.196,	Train acc: 52.907
# Training 29/100:	Train loss: 1.193,	Train acc: 53.961
# Training 30/100:	Train loss: 1.183,	Train acc: 54.427
# Training 31/100:	Train loss: 1.194,	Train acc: 53.176
# Training 32/100:	Train loss: 1.194,	Train acc: 53.520
# Training 33/100:	Train loss: 1.186,	Train acc: 54.305
# Training 34/100:	Train loss: 1.185,	Train acc: 54.623
# Training 35/100:	Train loss: 1.182,	Train acc: 54.918
# Training 36/100:	Train loss: 1.178,	Train acc: 55.703
# Training 37/100:	Train loss: 1.183,	Train acc: 54.403
# Training 38/100:	Train loss: 1.178,	Train acc: 55.703
# Training 39/100:	Train loss: 1.177,	Train acc: 55.899
# Training 40/100:	Train loss: 1.179,	Train acc: 54.918
# Training 41/100:	Train loss: 1.170,	Train acc: 56.586
# Training 42/100:	Train loss: 1.162,	Train acc: 56.905
# Training 43/100:	Train loss: 1.162,	Train acc: 56.782
# Training 44/100:	Train loss: 1.173,	Train acc: 55.580
# Training 45/100:	Train loss: 1.171,	Train acc: 56.316
# Training 46/100:	Train loss: 1.160,	Train acc: 57.174
# Training 47/100:	Train loss: 1.155,	Train acc: 58.842
# Training 48/100:	Train loss: 1.161,	Train acc: 56.708
# Training 49/100:	Train loss: 1.161,	Train acc: 57.248
# Training 50/100:	Train loss: 1.156,	Train acc: 57.444
# Training 51/100:	Train loss: 1.154,	Train acc: 57.395
# Training 52/100:	Train loss: 1.153,	Train acc: 58.622
# Training 53/100:	Train loss: 1.153,	Train acc: 58.352
# Training 54/100:	Train loss: 1.153,	Train acc: 58.523
# Training 55/100:	Train loss: 1.157,	Train acc: 57.493
# Training 56/100:	Train loss: 1.148,	Train acc: 58.057
# Training 57/100:	Train loss: 1.147,	Train acc: 58.474
# Training 58/100:	Train loss: 1.152,	Train acc: 58.033
# Training 59/100:	Train loss: 1.136,	Train acc: 60.020
# Training 60/100:	Train loss: 1.142,	Train acc: 59.063
# Training 61/100:	Train loss: 1.148,	Train acc: 59.406
# Training 62/100:	Train loss: 1.139,	Train acc: 59.627
# Training 63/100:	Train loss: 1.134,	Train acc: 59.652
# Training 64/100:	Train loss: 1.136,	Train acc: 58.867
# Training 65/100:	Train loss: 1.143,	Train acc: 58.180
# Training 66/100:	Train loss: 1.137,	Train acc: 60.240
# Training 67/100:	Train loss: 1.136,	Train acc: 60.461
# Training 68/100:	Train loss: 1.143,	Train acc: 59.235
# Training 69/100:	Train loss: 1.144,	Train acc: 59.480
# Training 70/100:	Train loss: 1.140,	Train acc: 59.529
# Training 71/100:	Train loss: 1.137,	Train acc: 59.897
# Training 72/100:	Train loss: 1.134,	Train acc: 60.142
# Training 73/100:	Train loss: 1.139,	Train acc: 58.965
# Training 74/100:	Train loss: 1.141,	Train acc: 60.093
# Training 75/100:	Train loss: 1.128,	Train acc: 60.878
# Training 76/100:	Train loss: 1.134,	Train acc: 59.799
# Training 77/100:	Train loss: 1.125,	Train acc: 60.755
# Training 78/100:	Train loss: 1.126,	Train acc: 61.099
# Training 79/100:	Train loss: 1.134,	Train acc: 60.069
# Training 80/100:	Train loss: 1.130,	Train acc: 60.535
# Training 81/100:	Train loss: 1.126,	Train acc: 60.584
# Training 82/100:	Train loss: 1.122,	Train acc: 61.148
# Training 83/100:	Train loss: 1.119,	Train acc: 62.203
# Training 84/100:	Train loss: 1.127,	Train acc: 60.657
# Training 85/100:	Train loss: 1.130,	Train acc: 60.829
# Training 86/100:	Train loss: 1.124,	Train acc: 60.952
# Training 87/100:	Train loss: 1.116,	Train acc: 62.252
# Training 88/100:	Train loss: 1.124,	Train acc: 61.491
# Training 89/100:	Train loss: 1.118,	Train acc: 62.031
# Training 90/100:	Train loss: 1.120,	Train acc: 62.129
# Training 91/100:	Train loss: 1.123,	Train acc: 61.810
# Training 92/100:	Train loss: 1.116,	Train acc: 61.908
# Training 93/100:	Train loss: 1.119,	Train acc: 61.589
# Training 94/100:	Train loss: 1.115,	Train acc: 61.957
# Training 95/100:	Train loss: 1.115,	Train acc: 62.399
# Training 96/100:	Train loss: 1.105,	Train acc: 63.478
# Training 97/100:	Train loss: 1.115,	Train acc: 62.276
# Training 98/100:	Train loss: 1.107,	Train acc: 63.503
# Training 99/100:	Train loss: 1.114,	Train acc: 62.669
# Training 100/100:	Train loss: 1.116,	Train acc: 61.761
# Train 2/5:	Train loss: 1.175,	Train acc: 55.645
# Test:	Test loss: 1.137,	Test acc: 60.275
# Test 2/5:	Test loss: 1.137,	Test acc: 60.275
# Fold 3/5
# Training 1/100:	Train loss: 1.370,	Train acc: 32.696
# Training 2/100:	Train loss: 1.356,	Train acc: 34.143
# Training 3/100:	Train loss: 1.334,	Train acc: 37.258
# Training 4/100:	Train loss: 1.322,	Train acc: 39.563
# Training 5/100:	Train loss: 1.312,	Train acc: 40.029
# Training 6/100:	Train loss: 1.299,	Train acc: 41.329
# Training 7/100:	Train loss: 1.299,	Train acc: 41.182
# Training 8/100:	Train loss: 1.287,	Train acc: 43.758
# Training 9/100:	Train loss: 1.277,	Train acc: 44.935
# Training 10/100:	Train loss: 1.278,	Train acc: 43.488
# Training 11/100:	Train loss: 1.268,	Train acc: 44.175
# Training 12/100:	Train loss: 1.263,	Train acc: 45.426
# Training 13/100:	Train loss: 1.249,	Train acc: 47.707
# Training 14/100:	Train loss: 1.240,	Train acc: 47.805
# Training 15/100:	Train loss: 1.236,	Train acc: 49.203
# Training 16/100:	Train loss: 1.240,	Train acc: 47.314
# Training 17/100:	Train loss: 1.236,	Train acc: 49.056
# Training 18/100:	Train loss: 1.222,	Train acc: 50.699
# Training 19/100:	Train loss: 1.226,	Train acc: 49.350
# Training 20/100:	Train loss: 1.223,	Train acc: 50.282
# Training 21/100:	Train loss: 1.215,	Train acc: 50.429
# Training 22/100:	Train loss: 1.208,	Train acc: 52.048
# Training 23/100:	Train loss: 1.210,	Train acc: 51.459
# Training 24/100:	Train loss: 1.201,	Train acc: 52.220
# Training 25/100:	Train loss: 1.204,	Train acc: 52.244
# Training 26/100:	Train loss: 1.199,	Train acc: 52.220
# Training 27/100:	Train loss: 1.199,	Train acc: 53.397
# Training 28/100:	Train loss: 1.195,	Train acc: 52.514
# Training 29/100:	Train loss: 1.189,	Train acc: 54.427
# Training 30/100:	Train loss: 1.189,	Train acc: 54.133
# Training 31/100:	Train loss: 1.193,	Train acc: 52.833
# Training 32/100:	Train loss: 1.189,	Train acc: 54.157
# Training 33/100:	Train loss: 1.192,	Train acc: 53.642
# Training 34/100:	Train loss: 1.182,	Train acc: 54.673
# Training 35/100:	Train loss: 1.189,	Train acc: 54.059
# Training 36/100:	Train loss: 1.184,	Train acc: 54.942
# Training 37/100:	Train loss: 1.182,	Train acc: 54.329
# Training 38/100:	Train loss: 1.178,	Train acc: 54.574
# Training 39/100:	Train loss: 1.176,	Train acc: 54.574
# Training 40/100:	Train loss: 1.176,	Train acc: 54.550
# Training 41/100:	Train loss: 1.175,	Train acc: 55.286
# Training 42/100:	Train loss: 1.169,	Train acc: 56.806
# Training 43/100:	Train loss: 1.172,	Train acc: 56.022
# Training 44/100:	Train loss: 1.167,	Train acc: 55.654
# Training 45/100:	Train loss: 1.166,	Train acc: 56.831
# Training 46/100:	Train loss: 1.165,	Train acc: 56.439
# Training 47/100:	Train loss: 1.166,	Train acc: 56.561
# Training 48/100:	Train loss: 1.162,	Train acc: 57.125
# Training 49/100:	Train loss: 1.155,	Train acc: 56.856
# Training 50/100:	Train loss: 1.156,	Train acc: 57.322
# Training 51/100:	Train loss: 1.156,	Train acc: 57.150
# Training 52/100:	Train loss: 1.154,	Train acc: 57.346
# Training 53/100:	Train loss: 1.160,	Train acc: 57.101
# Training 54/100:	Train loss: 1.150,	Train acc: 58.254
# Training 55/100:	Train loss: 1.151,	Train acc: 58.278
# Training 56/100:	Train loss: 1.154,	Train acc: 57.027
# Training 57/100:	Train loss: 1.145,	Train acc: 59.161
# Training 58/100:	Train loss: 1.141,	Train acc: 59.259
# Training 59/100:	Train loss: 1.143,	Train acc: 58.989
# Training 60/100:	Train loss: 1.145,	Train acc: 58.744
# Training 61/100:	Train loss: 1.139,	Train acc: 59.455
# Training 62/100:	Train loss: 1.143,	Train acc: 58.695
# Training 63/100:	Train loss: 1.139,	Train acc: 59.382
# Training 64/100:	Train loss: 1.148,	Train acc: 59.063
# Training 65/100:	Train loss: 1.150,	Train acc: 58.180
# Training 66/100:	Train loss: 1.135,	Train acc: 59.946
# Training 67/100:	Train loss: 1.132,	Train acc: 59.995
# Training 68/100:	Train loss: 1.132,	Train acc: 59.897
# Training 69/100:	Train loss: 1.137,	Train acc: 58.916
# Training 70/100:	Train loss: 1.132,	Train acc: 60.461
# Training 71/100:	Train loss: 1.135,	Train acc: 60.314
# Training 72/100:	Train loss: 1.142,	Train acc: 59.505
# Training 73/100:	Train loss: 1.125,	Train acc: 60.706
# Training 74/100:	Train loss: 1.134,	Train acc: 59.652
# Training 75/100:	Train loss: 1.123,	Train acc: 61.295
# Training 76/100:	Train loss: 1.133,	Train acc: 60.240
# Training 77/100:	Train loss: 1.129,	Train acc: 61.050
# Training 78/100:	Train loss: 1.121,	Train acc: 60.854
# Training 79/100:	Train loss: 1.126,	Train acc: 60.608
# Training 80/100:	Train loss: 1.123,	Train acc: 61.320
# Training 81/100:	Train loss: 1.128,	Train acc: 60.412
# Training 82/100:	Train loss: 1.121,	Train acc: 60.608
# Training 83/100:	Train loss: 1.124,	Train acc: 61.025
# Training 84/100:	Train loss: 1.121,	Train acc: 60.854
# Training 85/100:	Train loss: 1.124,	Train acc: 61.467
# Training 86/100:	Train loss: 1.118,	Train acc: 61.320
# Training 87/100:	Train loss: 1.118,	Train acc: 61.908
# Training 88/100:	Train loss: 1.109,	Train acc: 62.031
# Training 89/100:	Train loss: 1.118,	Train acc: 61.369
# Training 90/100:	Train loss: 1.108,	Train acc: 62.472
# Training 91/100:	Train loss: 1.114,	Train acc: 62.129
# Training 92/100:	Train loss: 1.110,	Train acc: 61.982
# Training 93/100:	Train loss: 1.108,	Train acc: 63.086
# Training 94/100:	Train loss: 1.111,	Train acc: 62.252
# Training 95/100:	Train loss: 1.110,	Train acc: 62.154
# Training 96/100:	Train loss: 1.115,	Train acc: 61.982
# Training 97/100:	Train loss: 1.111,	Train acc: 62.154
# Training 98/100:	Train loss: 1.104,	Train acc: 63.086
# Training 99/100:	Train loss: 1.109,	Train acc: 62.031
# Training 100/100:	Train loss: 1.111,	Train acc: 62.497
# Train 3/5:	Train loss: 1.175,	Train acc: 55.294
# Test:	Test loss: 1.093,	Test acc: 61.903
# Test 3/5:	Test loss: 1.093,	Test acc: 61.903
# Fold 4/5
# Training 1/100:	Train loss: 1.370,	Train acc: 32.377
# Training 2/100:	Train loss: 1.351,	Train acc: 35.418
# Training 3/100:	Train loss: 1.333,	Train acc: 37.331
# Training 4/100:	Train loss: 1.327,	Train acc: 38.484
# Training 5/100:	Train loss: 1.315,	Train acc: 40.348
# Training 6/100:	Train loss: 1.307,	Train acc: 40.692
# Training 7/100:	Train loss: 1.288,	Train acc: 42.826
# Training 8/100:	Train loss: 1.279,	Train acc: 44.101
# Training 9/100:	Train loss: 1.276,	Train acc: 44.690
# Training 10/100:	Train loss: 1.267,	Train acc: 45.843
# Training 11/100:	Train loss: 1.261,	Train acc: 45.646
# Training 12/100:	Train loss: 1.260,	Train acc: 46.701
# Training 13/100:	Train loss: 1.242,	Train acc: 48.246
# Training 14/100:	Train loss: 1.243,	Train acc: 48.541
# Training 15/100:	Train loss: 1.240,	Train acc: 48.982
# Training 16/100:	Train loss: 1.234,	Train acc: 49.056
# Training 17/100:	Train loss: 1.232,	Train acc: 48.737
# Training 18/100:	Train loss: 1.232,	Train acc: 49.890
# Training 19/100:	Train loss: 1.221,	Train acc: 50.944
# Training 20/100:	Train loss: 1.212,	Train acc: 51.974
# Training 21/100:	Train loss: 1.208,	Train acc: 52.269
# Training 22/100:	Train loss: 1.205,	Train acc: 52.931
# Training 23/100:	Train loss: 1.208,	Train acc: 51.925
# Training 24/100:	Train loss: 1.208,	Train acc: 51.386
# Training 25/100:	Train loss: 1.205,	Train acc: 52.907
# Training 26/100:	Train loss: 1.200,	Train acc: 53.397
# Training 27/100:	Train loss: 1.190,	Train acc: 54.771
# Training 28/100:	Train loss: 1.193,	Train acc: 53.618
# Training 29/100:	Train loss: 1.187,	Train acc: 54.501
# Training 30/100:	Train loss: 1.181,	Train acc: 55.457
# Training 31/100:	Train loss: 1.188,	Train acc: 54.305
# Training 32/100:	Train loss: 1.190,	Train acc: 53.446
# Training 33/100:	Train loss: 1.192,	Train acc: 53.716
# Training 34/100:	Train loss: 1.177,	Train acc: 55.359
# Training 35/100:	Train loss: 1.175,	Train acc: 55.776
# Training 36/100:	Train loss: 1.178,	Train acc: 55.212
# Training 37/100:	Train loss: 1.177,	Train acc: 55.727
# Training 38/100:	Train loss: 1.172,	Train acc: 56.488
# Training 39/100:	Train loss: 1.177,	Train acc: 55.114
# Training 40/100:	Train loss: 1.166,	Train acc: 56.905
# Training 41/100:	Train loss: 1.165,	Train acc: 56.365
# Training 42/100:	Train loss: 1.166,	Train acc: 57.076
# Training 43/100:	Train loss: 1.163,	Train acc: 56.684
# Training 44/100:	Train loss: 1.156,	Train acc: 58.057
# Training 45/100:	Train loss: 1.161,	Train acc: 57.003
# Training 46/100:	Train loss: 1.153,	Train acc: 57.935
# Training 47/100:	Train loss: 1.162,	Train acc: 57.444
# Training 48/100:	Train loss: 1.154,	Train acc: 57.861
# Training 49/100:	Train loss: 1.158,	Train acc: 56.905
# Training 50/100:	Train loss: 1.154,	Train acc: 58.057
# Training 51/100:	Train loss: 1.151,	Train acc: 58.499
# Training 52/100:	Train loss: 1.152,	Train acc: 58.671
# Training 53/100:	Train loss: 1.152,	Train acc: 57.886
# Training 54/100:	Train loss: 1.149,	Train acc: 58.082
# Training 55/100:	Train loss: 1.150,	Train acc: 59.039
# Training 56/100:	Train loss: 1.145,	Train acc: 58.720
# Training 57/100:	Train loss: 1.143,	Train acc: 59.406
# Training 58/100:	Train loss: 1.141,	Train acc: 59.039
# Training 59/100:	Train loss: 1.145,	Train acc: 59.529
# Training 60/100:	Train loss: 1.146,	Train acc: 59.308
# Training 61/100:	Train loss: 1.141,	Train acc: 59.603
# Training 62/100:	Train loss: 1.142,	Train acc: 59.750
# Training 63/100:	Train loss: 1.142,	Train acc: 59.357
# Training 64/100:	Train loss: 1.134,	Train acc: 60.486
# Training 65/100:	Train loss: 1.129,	Train acc: 59.995
# Training 66/100:	Train loss: 1.134,	Train acc: 59.088
# Training 67/100:	Train loss: 1.138,	Train acc: 59.088
# Training 68/100:	Train loss: 1.129,	Train acc: 60.608
# Training 69/100:	Train loss: 1.135,	Train acc: 59.971
# Training 70/100:	Train loss: 1.135,	Train acc: 60.093
# Training 71/100:	Train loss: 1.121,	Train acc: 61.369
# Training 72/100:	Train loss: 1.123,	Train acc: 61.172
# Training 73/100:	Train loss: 1.123,	Train acc: 61.638
# Training 74/100:	Train loss: 1.127,	Train acc: 61.271
# Training 75/100:	Train loss: 1.129,	Train acc: 60.486
# Training 76/100:	Train loss: 1.117,	Train acc: 61.467
# Training 77/100:	Train loss: 1.128,	Train acc: 60.927
# Training 78/100:	Train loss: 1.121,	Train acc: 61.271
# Training 79/100:	Train loss: 1.117,	Train acc: 61.786
# Training 80/100:	Train loss: 1.116,	Train acc: 61.761
# Training 81/100:	Train loss: 1.124,	Train acc: 60.633
# Training 82/100:	Train loss: 1.123,	Train acc: 60.755
# Training 83/100:	Train loss: 1.112,	Train acc: 62.276
# Training 84/100:	Train loss: 1.118,	Train acc: 61.933
# Training 85/100:	Train loss: 1.105,	Train acc: 63.061
# Training 86/100:	Train loss: 1.119,	Train acc: 61.320
# Training 87/100:	Train loss: 1.116,	Train acc: 61.933
# Training 88/100:	Train loss: 1.118,	Train acc: 61.761
# Training 89/100:	Train loss: 1.116,	Train acc: 62.521
# Training 90/100:	Train loss: 1.114,	Train acc: 62.031
# Training 91/100:	Train loss: 1.111,	Train acc: 62.154
# Training 92/100:	Train loss: 1.111,	Train acc: 62.914
# Training 93/100:	Train loss: 1.108,	Train acc: 63.037
# Training 94/100:	Train loss: 1.107,	Train acc: 62.423
# Training 95/100:	Train loss: 1.112,	Train acc: 61.369
# Training 96/100:	Train loss: 1.109,	Train acc: 63.282
# Training 97/100:	Train loss: 1.105,	Train acc: 63.282
# Training 98/100:	Train loss: 1.106,	Train acc: 62.571
# Training 99/100:	Train loss: 1.111,	Train acc: 62.693
# Training 100/100:	Train loss: 1.117,	Train acc: 62.031
# Train 4/5:	Train loss: 1.172,	Train acc: 55.928
# Test:	Test loss: 1.125,	Test acc: 61.688
# Test 4/5:	Test loss: 1.125,	Test acc: 61.688
# Fold 5/5
# Training 1/100:	Train loss: 1.365,	Train acc: 34.069
# Training 2/100:	Train loss: 1.335,	Train acc: 37.307
# Training 3/100:	Train loss: 1.332,	Train acc: 37.037
# Training 4/100:	Train loss: 1.315,	Train acc: 40.324
# Training 5/100:	Train loss: 1.306,	Train acc: 40.618
# Training 6/100:	Train loss: 1.298,	Train acc: 41.624
# Training 7/100:	Train loss: 1.287,	Train acc: 42.335
# Training 8/100:	Train loss: 1.279,	Train acc: 44.690
# Training 9/100:	Train loss: 1.269,	Train acc: 45.695
# Training 10/100:	Train loss: 1.259,	Train acc: 45.843
# Training 11/100:	Train loss: 1.259,	Train acc: 46.186
# Training 12/100:	Train loss: 1.250,	Train acc: 47.707
# Training 13/100:	Train loss: 1.241,	Train acc: 48.909
# Training 14/100:	Train loss: 1.236,	Train acc: 48.958
# Training 15/100:	Train loss: 1.228,	Train acc: 49.473
# Training 16/100:	Train loss: 1.221,	Train acc: 50.429
# Training 17/100:	Train loss: 1.224,	Train acc: 50.086
# Training 18/100:	Train loss: 1.214,	Train acc: 51.361
# Training 19/100:	Train loss: 1.213,	Train acc: 51.827
# Training 20/100:	Train loss: 1.203,	Train acc: 52.833
# Training 21/100:	Train loss: 1.202,	Train acc: 52.661
# Training 22/100:	Train loss: 1.205,	Train acc: 52.857
# Training 23/100:	Train loss: 1.200,	Train acc: 52.980
# Training 24/100:	Train loss: 1.200,	Train acc: 53.716
# Training 25/100:	Train loss: 1.188,	Train acc: 54.378
# Training 26/100:	Train loss: 1.194,	Train acc: 53.299
# Training 27/100:	Train loss: 1.187,	Train acc: 54.059
# Training 28/100:	Train loss: 1.190,	Train acc: 54.231
# Training 29/100:	Train loss: 1.185,	Train acc: 54.746
# Training 30/100:	Train loss: 1.180,	Train acc: 55.188
# Training 31/100:	Train loss: 1.177,	Train acc: 54.844
# Training 32/100:	Train loss: 1.175,	Train acc: 55.286
# Training 33/100:	Train loss: 1.172,	Train acc: 56.757
# Training 34/100:	Train loss: 1.176,	Train acc: 55.923
# Training 35/100:	Train loss: 1.167,	Train acc: 56.733
# Training 36/100:	Train loss: 1.168,	Train acc: 56.390
# Training 37/100:	Train loss: 1.168,	Train acc: 56.390
# Training 38/100:	Train loss: 1.165,	Train acc: 56.684
# Training 39/100:	Train loss: 1.168,	Train acc: 56.488
# Training 40/100:	Train loss: 1.161,	Train acc: 57.125
# Training 41/100:	Train loss: 1.156,	Train acc: 57.199
# Training 42/100:	Train loss: 1.158,	Train acc: 57.739
# Training 43/100:	Train loss: 1.157,	Train acc: 57.248
# Training 44/100:	Train loss: 1.161,	Train acc: 57.371
# Training 45/100:	Train loss: 1.161,	Train acc: 56.708
# Training 46/100:	Train loss: 1.155,	Train acc: 57.346
# Training 47/100:	Train loss: 1.160,	Train acc: 57.101
# Training 48/100:	Train loss: 1.149,	Train acc: 58.254
# Training 49/100:	Train loss: 1.150,	Train acc: 58.425
# Training 50/100:	Train loss: 1.143,	Train acc: 58.646
# Training 51/100:	Train loss: 1.147,	Train acc: 59.480
# Training 52/100:	Train loss: 1.144,	Train acc: 59.627
# Training 53/100:	Train loss: 1.140,	Train acc: 59.063
# Training 54/100:	Train loss: 1.143,	Train acc: 58.671
# Training 55/100:	Train loss: 1.136,	Train acc: 60.265
# Training 56/100:	Train loss: 1.144,	Train acc: 59.112
# Training 57/100:	Train loss: 1.134,	Train acc: 60.069
# Training 58/100:	Train loss: 1.139,	Train acc: 60.338
# Training 59/100:	Train loss: 1.140,	Train acc: 58.769
# Training 60/100:	Train loss: 1.124,	Train acc: 61.344
# Training 61/100:	Train loss: 1.130,	Train acc: 59.971
# Training 62/100:	Train loss: 1.139,	Train acc: 58.940
# Training 63/100:	Train loss: 1.125,	Train acc: 60.682
# Training 64/100:	Train loss: 1.130,	Train acc: 60.755
# Training 65/100:	Train loss: 1.134,	Train acc: 59.995
# Training 66/100:	Train loss: 1.120,	Train acc: 61.393
# Training 67/100:	Train loss: 1.121,	Train acc: 61.050
# Training 68/100:	Train loss: 1.122,	Train acc: 61.074
# Training 69/100:	Train loss: 1.123,	Train acc: 61.786
# Training 70/100:	Train loss: 1.123,	Train acc: 60.903
# Training 71/100:	Train loss: 1.128,	Train acc: 60.069
# Training 72/100:	Train loss: 1.127,	Train acc: 61.172
# Training 73/100:	Train loss: 1.123,	Train acc: 61.050
# Training 74/100:	Train loss: 1.120,	Train acc: 61.491
# Training 75/100:	Train loss: 1.123,	Train acc: 60.927
# Training 76/100:	Train loss: 1.116,	Train acc: 61.295
# Training 77/100:	Train loss: 1.124,	Train acc: 60.486
# Training 78/100:	Train loss: 1.116,	Train acc: 62.350
# Training 79/100:	Train loss: 1.113,	Train acc: 62.252
# Training 80/100:	Train loss: 1.114,	Train acc: 62.399
# Training 81/100:	Train loss: 1.113,	Train acc: 62.006
# Training 82/100:	Train loss: 1.112,	Train acc: 61.957
# Training 83/100:	Train loss: 1.106,	Train acc: 62.963
# Training 84/100:	Train loss: 1.107,	Train acc: 62.620
# Training 85/100:	Train loss: 1.104,	Train acc: 63.478
# Training 86/100:	Train loss: 1.117,	Train acc: 61.835
# Training 87/100:	Train loss: 1.111,	Train acc: 62.301
# Training 88/100:	Train loss: 1.098,	Train acc: 63.870
# Training 89/100:	Train loss: 1.102,	Train acc: 63.699
# Training 90/100:	Train loss: 1.107,	Train acc: 62.767
# Training 91/100:	Train loss: 1.103,	Train acc: 63.135
# Training 92/100:	Train loss: 1.108,	Train acc: 62.693
# Training 93/100:	Train loss: 1.106,	Train acc: 63.650
# Training 94/100:	Train loss: 1.101,	Train acc: 63.748
# Training 95/100:	Train loss: 1.105,	Train acc: 63.086
# Training 96/100:	Train loss: 1.102,	Train acc: 63.454
# Training 97/100:	Train loss: 1.105,	Train acc: 63.012
# Training 98/100:	Train loss: 1.095,	Train acc: 64.214
# Training 99/100:	Train loss: 1.098,	Train acc: 63.380
# Training 100/100:	Train loss: 1.100,	Train acc: 63.601
# Train 5/5:	Train loss: 1.165,	Train acc: 56.623
# Test:	Test loss: 1.138,	Test acc: 60.989
# Test 5/5:	Test loss: 1.138,	Test acc: 60.989

# %%
# plt.figure(figsize=(10, 5))
# plt.plot(train_accuracies, label='Train Accuracy')
# plt.plot(val_accuracies, label='Val Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')
# plt.title('Train and Val Accuracy')
# plt.legend()
# plt.show()

# plt.figure(figsize=(10, 5))
# plt.plot(train_losses, label='Train Loss')
# plt.plot(val_losses, label='Val Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Train and Val Loss')
# plt.legend()
# plt.show()

# %%
classes = ['Spring', 'Summer', 'Fall', 'Winter'] if dataset.n_classes == 4 else ['Warm', 'Cool']

# %%
cm = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cm, index=classes, columns=classes)

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(df_cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
writer.add_figure('confusion_matrix', plt.gcf())
