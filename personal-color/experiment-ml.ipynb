# %%
import pandas as pd
import os

# %%
# os.environ["OMP_NUM_THREADS"] = '1'
import warnings
warnings.filterwarnings('ignore')

# %%
warm_only_df = pd.read_csv('images/dataset__/mean_warm.csv')
cool_only_df = pd.read_csv('images/dataset__/mean_cool.csv')
warm_cool_df = pd.read_csv('images/dataset__/mean_warm_cool.csv')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
warm_only_df['label'] = le.fit_transform(warm_only_df['label'])
corr = warm_only_df.corr()
corr['label'].sort_values(ascending=False)
# Out:
# label         1.000000
# R             0.684662
# G             0.662994
# B             0.612985
# L             0.595482
# V             0.548094
# face_l_var    0.515013
# lips_s       -0.126989
# H            -0.196292
# skin_avg_b   -0.363210
# a            -0.370926
# b            -0.418580
# S            -0.528928
# Name: label, dtype: float64

# %%
cool_only_df['label'] = le.fit_transform(cool_only_df['label'])
corr = cool_only_df.corr()
corr['label'].sort_values(ascending=False)
# Out:
# label         1.000000
# S             0.324579
# b             0.266293
# skin_avg_b    0.264221
# lips_s        0.156504
# a             0.136844
# V            -0.099890
# face_l_var   -0.118810
# H            -0.128745
# B            -0.129263
# L            -0.178399
# G            -0.213205
# R            -0.280630
# Name: label, dtype: float64

# %%
warm_cool_df['label'] = le.fit_transform(warm_cool_df['label'])
corr = warm_cool_df.corr()
corr['label'].sort_values(ascending=False)
# Out:
# label         1.000000
# R             0.674116
# L             0.494292
# G             0.426816
# H             0.347399
# V             0.262493
# B             0.159047
# face_l_var    0.149772
# lips_s       -0.092114
# a            -0.392378
# S            -0.749244
# skin_avg_b   -0.758076
# b            -0.760325
# Name: label, dtype: float64

# %%
from sklearn.model_selection import cross_val_score

# %%
# normalize
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# scale
warm_only_df.iloc[:, :-1] = scaler.fit_transform(warm_only_df.iloc[:, :-1])
cool_only_df.iloc[:, :-1] = scaler.fit_transform(cool_only_df.iloc[:, :-1])
warm_cool_df.iloc[:, :-1] = scaler.fit_transform(warm_cool_df.iloc[:, :-1])

# %%
# warm only

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X = warm_only_df.iloc[:, :-1]
y = warm_only_df['label']

# %%
for i in range(1, 30):
    clf = KNeighborsClassifier(n_neighbors=i)
    scores = cross_val_score(clf, X, y, cv=5).mean()
    print(f'KNN {i}: {scores}')
# Out:
# KNN 1: 0.7300653594771241
# KNN 2: 0.742483660130719
# KNN 3: 0.7862745098039216
# KNN 4: 0.8196078431372549
# KNN 5: 0.8431372549019608
# KNN 6: 0.8431372549019608
# KNN 7: 0.8431372549019608
# KNN 8: 0.8431372549019608
# KNN 9: 0.830718954248366
# KNN 10: 0.8431372549019607
# KNN 11: 0.8542483660130719
# KNN 12: 0.8653594771241829
# KNN 13: 0.842483660130719
# KNN 14: 0.8542483660130719
# KNN 15: 0.8431372549019608
# KNN 16: 0.8542483660130719
# KNN 17: 0.85359477124183
# KNN 18: 0.842483660130719
# KNN 19: 0.8313725490196079
# KNN 20: 0.842483660130719
# KNN 21: 0.842483660130719
# KNN 22: 0.8313725490196079
# KNN 23: 0.842483660130719
# KNN 24: 0.842483660130719
# KNN 25: 0.8313725490196079
# KNN 26: 0.85359477124183
# KNN 27: 0.8313725490196079
# KNN 28: 0.8202614379084967
# KNN 29: 0.8313725490196079

# %%
for i in range(1, 30):
    clf = DecisionTreeClassifier(max_depth=i)
    scores = cross_val_score(clf, X, y, cv=5).mean()
    print(f'Decision Tree {i}: {scores}')
# Out:
# Decision Tree 1: 0.7967320261437909
# Decision Tree 2: 0.842483660130719
# Decision Tree 3: 0.7640522875816993
# Decision Tree 4: 0.7751633986928104
# Decision Tree 5: 0.7529411764705882
# Decision Tree 6: 0.7862745098039217
# Decision Tree 7: 0.7633986928104577
# Decision Tree 8: 0.7745098039215688
# Decision Tree 9: 0.7640522875816993
# Decision Tree 10: 0.7862745098039217
# Decision Tree 11: 0.7973856209150327
# Decision Tree 12: 0.7418300653594772
# Decision Tree 13: 0.7529411764705882
# Decision Tree 14: 0.741830065359477
# Decision Tree 15: 0.7862745098039217
# Decision Tree 16: 0.7529411764705882
# Decision Tree 17: 0.7751633986928104
# Decision Tree 18: 0.7751633986928104
# Decision Tree 19: 0.7862745098039217
# Decision Tree 20: 0.7640522875816993
# Decision Tree 21: 0.8196078431372549
# Decision Tree 22: 0.7418300653594772
# Decision Tree 23: 0.7640522875816993
# Decision Tree 24: 0.7862745098039216
# Decision Tree 25: 0.7751633986928104
# Decision Tree 26: 0.7640522875816993
# Decision Tree 27: 0.7751633986928104
# Decision Tree 28: 0.7529411764705882
# Decision Tree 29: 0.7418300653594772

# %%
# rf
n_estimators = range(1, 500, 10)
loss = ['gini', 'entropy']

# %%
for n in n_estimators:
    for l in loss:
        clf = RandomForestClassifier(n_estimators=n, criterion=l)
        scores = cross_val_score(clf, X, y, cv=5).mean()
        print(f'Random Forest {n} {l}: {scores}')
# Out:
# Random Forest 1 gini: 0.8091503267973856
# Random Forest 1 entropy: 0.6954248366013072
# Random Forest 11 gini: 0.8091503267973856
# Random Forest 11 entropy: 0.85359477124183
# Random Forest 21 gini: 0.842483660130719
# Random Forest 21 entropy: 0.8542483660130719
# Random Forest 31 gini: 0.8320261437908496
# Random Forest 31 entropy: 0.8313725490196078
# Random Forest 41 gini: 0.8091503267973856
# Random Forest 41 entropy: 0.8320261437908496
# Random Forest 51 gini: 0.8209150326797385
# Random Forest 51 entropy: 0.8209150326797385
# Random Forest 61 gini: 0.8313725490196078
# Random Forest 61 entropy: 0.8209150326797385
# Random Forest 71 gini: 0.8320261437908496
# Random Forest 71 entropy: 0.8431372549019607
# Random Forest 81 gini: 0.8098039215686275
# Random Forest 81 entropy: 0.8313725490196078
# Random Forest 91 gini: 0.8320261437908496
# Random Forest 91 entropy: 0.8209150326797385
# Random Forest 101 gini: 0.8431372549019607
# Random Forest 101 entropy: 0.8202614379084967
# Random Forest 111 gini: 0.8098039215686275
# Random Forest 111 entropy: 0.8431372549019607
# Random Forest 121 gini: 0.8542483660130719
# Random Forest 121 entropy: 0.8313725490196078
# Random Forest 131 gini: 0.8313725490196079
# Random Forest 131 entropy: 0.8313725490196078
# Random Forest 141 gini: 0.8098039215686275
# Random Forest 141 entropy: 0.8313725490196078
# Random Forest 151 gini: 0.8320261437908496
# Random Forest 151 entropy: 0.8320261437908496
# Random Forest 161 gini: 0.8209150326797385
# Random Forest 161 entropy: 0.8431372549019607
# Random Forest 171 gini: 0.8209150326797385
# Random Forest 171 entropy: 0.8202614379084967
# Random Forest 181 gini: 0.8091503267973856
# Random Forest 181 entropy: 0.8320261437908496
# Random Forest 191 gini: 0.8431372549019607
# Random Forest 191 entropy: 0.8431372549019607
# Random Forest 201 gini: 0.8320261437908496
# Random Forest 201 entropy: 0.8313725490196078
# Random Forest 211 gini: 0.8320261437908496
# Random Forest 211 entropy: 0.8202614379084967
# Random Forest 221 gini: 0.8313725490196078
# Random Forest 221 entropy: 0.8313725490196078
# Random Forest 231 gini: 0.8202614379084967
# Random Forest 231 entropy: 0.8320261437908496
# Random Forest 241 gini: 0.8320261437908496
# Random Forest 241 entropy: 0.8320261437908496
# Random Forest 251 gini: 0.8431372549019608
# Random Forest 251 entropy: 0.8313725490196078
# Random Forest 261 gini: 0.8091503267973856
# Random Forest 261 entropy: 0.8320261437908496
# Random Forest 271 gini: 0.8202614379084967
# Random Forest 271 entropy: 0.8431372549019607
# Random Forest 281 gini: 0.8313725490196079
# Random Forest 281 entropy: 0.8313725490196078
# Random Forest 291 gini: 0.8091503267973856
# Random Forest 291 entropy: 0.8320261437908496
# Random Forest 301 gini: 0.8313725490196078
# Random Forest 301 entropy: 0.8320261437908496
# Random Forest 311 gini: 0.8209150326797385
# Random Forest 311 entropy: 0.8313725490196078
# Random Forest 321 gini: 0.8313725490196078
# Random Forest 321 entropy: 0.8320261437908496
# Random Forest 331 gini: 0.8098039215686275
# Random Forest 331 entropy: 0.8209150326797385
# Random Forest 341 gini: 0.8431372549019607
# Random Forest 341 entropy: 0.8431372549019607
# Random Forest 351 gini: 0.8313725490196078
# Random Forest 351 entropy: 0.8320261437908496
# Random Forest 361 gini: 0.8209150326797385
# Random Forest 361 entropy: 0.8431372549019607
# Random Forest 371 gini: 0.8313725490196078
# Random Forest 371 entropy: 0.8202614379084967
# Random Forest 381 gini: 0.8320261437908496
# Random Forest 381 entropy: 0.8542483660130719
# Random Forest 391 gini: 0.8313725490196078
# Random Forest 391 entropy: 0.8313725490196078
# Random Forest 401 gini: 0.8431372549019607
# Random Forest 401 entropy: 0.8202614379084967
# Random Forest 411 gini: 0.8431372549019607
# Random Forest 411 entropy: 0.8313725490196078
# Random Forest 421 gini: 0.8431372549019607
# Random Forest 421 entropy: 0.8313725490196078
# Random Forest 431 gini: 0.8431372549019607
# Random Forest 431 entropy: 0.8313725490196078
# Random Forest 441 gini: 0.842483660130719
# Random Forest 441 entropy: 0.8202614379084967
# Random Forest 451 gini: 0.8320261437908496
# Random Forest 451 entropy: 0.8313725490196078
# Random Forest 461 gini: 0.8313725490196078
# Random Forest 461 entropy: 0.8202614379084967
# Random Forest 471 gini: 0.8202614379084967
# Random Forest 471 entropy: 0.8320261437908496
# Random Forest 481 gini: 0.8542483660130719
# Random Forest 481 entropy: 0.8320261437908496
# Random Forest 491 gini: 0.8202614379084967
# Random Forest 491 entropy: 0.8313725490196078

# %%
kernel = ['linear', 'poly', 'rbf', 'sigmoid']
C = range(1, 9)
gamma = ['scale', 'auto']

# %%
for k in kernel:
    for c in C:
        for g in gamma:
            clf = SVC(kernel=k, C=c*10, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
            
            clf = SVC(kernel=k, C=c, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
            
            clf = SVC(kernel=k, C=c*.1, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
# Out:
# SVM linear 1 scale: 0.8660130718954248
# SVM linear 1 scale: 0.8660130718954248
# SVM linear 1 scale: 0.866013071895425
# SVM linear 1 auto: 0.8660130718954248
# SVM linear 1 auto: 0.8660130718954248
# SVM linear 1 auto: 0.866013071895425
# SVM linear 2 scale: 0.8771241830065358
# SVM linear 2 scale: 0.8653594771241829
# SVM linear 2 scale: 0.877124183006536
# SVM linear 2 auto: 0.8771241830065358
# SVM linear 2 auto: 0.8653594771241829
# SVM linear 2 auto: 0.877124183006536
# SVM linear 3 scale: 0.877124183006536
# SVM linear 3 scale: 0.8653594771241829
# SVM linear 3 scale: 0.877124183006536
# SVM linear 3 auto: 0.877124183006536
# SVM linear 3 auto: 0.8653594771241829
# SVM linear 3 auto: 0.877124183006536
# SVM linear 4 scale: 0.877124183006536
# SVM linear 4 scale: 0.8653594771241829
# SVM linear 4 scale: 0.8660130718954248
# SVM linear 4 auto: 0.877124183006536
# SVM linear 4 auto: 0.8653594771241829
# SVM linear 4 auto: 0.8660130718954248
# SVM linear 5 scale: 0.877124183006536
# SVM linear 5 scale: 0.8653594771241829
# SVM linear 5 scale: 0.8660130718954248
# SVM linear 5 auto: 0.877124183006536
# SVM linear 5 auto: 0.8653594771241829
# SVM linear 5 auto: 0.8660130718954248
# SVM linear 6 scale: 0.877124183006536
# SVM linear 6 scale: 0.8549019607843137
# SVM linear 6 scale: 0.8660130718954248
# SVM linear 6 auto: 0.877124183006536
# SVM linear 6 auto: 0.8549019607843137
# SVM linear 6 auto: 0.8660130718954248
# SVM linear 7 scale: 0.877124183006536
# SVM linear 7 scale: 0.8660130718954248
# SVM linear 7 scale: 0.8660130718954248
# SVM linear 7 auto: 0.877124183006536
# SVM linear 7 auto: 0.8660130718954248
# SVM linear 7 auto: 0.8660130718954248
# SVM linear 8 scale: 0.877124183006536
# SVM linear 8 scale: 0.8660130718954248
# SVM linear 8 scale: 0.8660130718954248
# SVM linear 8 auto: 0.877124183006536
# SVM linear 8 auto: 0.8660130718954248
# SVM linear 8 auto: 0.8660130718954248
# SVM poly 1 scale: 0.8300653594771241
# SVM poly 1 scale: 0.7411764705882353
# SVM poly 1 scale: 0.7078431372549019
# SVM poly 1 auto: 0.8300653594771241
# SVM poly 1 auto: 0.7411764705882353
# SVM poly 1 auto: 0.7078431372549019
# SVM poly 2 scale: 0.8300653594771242
# SVM poly 2 scale: 0.7522875816993464
# SVM poly 2 scale: 0.818954248366013
# SVM poly 2 auto: 0.8300653594771242
# SVM poly 2 auto: 0.7522875816993464
# SVM poly 2 auto: 0.7856209150326798
# SVM poly 3 scale: 0.8300653594771242
# SVM poly 3 scale: 0.7633986928104575
# SVM poly 3 scale: 0.8411764705882353
# SVM poly 3 auto: 0.8300653594771242
# SVM poly 3 auto: 0.7633986928104575
# SVM poly 3 auto: 0.8300653594771242
# SVM poly 4 scale: 0.8183006535947713
# SVM poly 4 scale: 0.8084967320261438
# SVM poly 4 scale: 0.7967320261437909
# SVM poly 4 auto: 0.8183006535947713
# SVM poly 4 auto: 0.8196078431372549
# SVM poly 4 auto: 0.807843137254902
# SVM poly 5 scale: 0.8071895424836601
# SVM poly 5 scale: 0.8196078431372549
# SVM poly 5 scale: 0.7522875816993465
# SVM poly 5 auto: 0.8071895424836601
# SVM poly 5 auto: 0.8196078431372549
# SVM poly 5 auto: 0.7522875816993465
# SVM poly 6 scale: 0.8071895424836601
# SVM poly 6 scale: 0.830718954248366
# SVM poly 6 scale: 0.7300653594771243
# SVM poly 6 auto: 0.8071895424836601
# SVM poly 6 auto: 0.830718954248366
# SVM poly 6 auto: 0.7300653594771243
# SVM poly 7 scale: 0.8300653594771242
# SVM poly 7 scale: 0.830718954248366
# SVM poly 7 scale: 0.7300653594771243
# SVM poly 7 auto: 0.807843137254902
# SVM poly 7 auto: 0.841830065359477
# SVM poly 7 auto: 0.7300653594771243
# SVM poly 8 scale: 0.818954248366013
# SVM poly 8 scale: 0.841830065359477
# SVM poly 8 scale: 0.7522875816993464
# SVM poly 8 auto: 0.818954248366013
# SVM poly 8 auto: 0.841830065359477
# SVM poly 8 auto: 0.7300653594771243
# SVM rbf 1 scale: 0.7751633986928104
# SVM rbf 1 scale: 0.8209150326797385
# SVM rbf 1 scale: 0.7980392156862746
# SVM rbf 1 auto: 0.7751633986928104
# SVM rbf 1 auto: 0.8209150326797385
# SVM rbf 1 auto: 0.7869281045751635
# SVM rbf 2 scale: 0.7640522875816993
# SVM rbf 2 scale: 0.8202614379084967
# SVM rbf 2 scale: 0.8313725490196078
# SVM rbf 2 auto: 0.7751633986928104
# SVM rbf 2 auto: 0.8202614379084967
# SVM rbf 2 auto: 0.8424836601307188
# SVM rbf 3 scale: 0.7529411764705882
# SVM rbf 3 scale: 0.8313725490196079
# SVM rbf 3 scale: 0.8424836601307188
# SVM rbf 3 auto: 0.7529411764705882
# SVM rbf 3 auto: 0.8202614379084967
# SVM rbf 3 auto: 0.8424836601307188
# SVM rbf 4 scale: 0.7758169934640522
# SVM rbf 4 scale: 0.8320261437908496
# SVM rbf 4 scale: 0.8313725490196078
# SVM rbf 4 auto: 0.7758169934640522
# SVM rbf 4 auto: 0.8431372549019608
# SVM rbf 4 auto: 0.8313725490196078
# SVM rbf 5 scale: 0.7875816993464052
# SVM rbf 5 scale: 0.7980392156862746
# SVM rbf 5 scale: 0.8431372549019607
# SVM rbf 5 auto: 0.7875816993464052
# SVM rbf 5 auto: 0.7869281045751633
# SVM rbf 5 auto: 0.8313725490196078
# SVM rbf 6 scale: 0.7758169934640522
# SVM rbf 6 scale: 0.7751633986928104
# SVM rbf 6 scale: 0.8431372549019607
# SVM rbf 6 auto: 0.7758169934640522
# SVM rbf 6 auto: 0.7751633986928104
# SVM rbf 6 auto: 0.8320261437908496
# SVM rbf 7 scale: 0.7875816993464052
# SVM rbf 7 scale: 0.7751633986928104
# SVM rbf 7 scale: 0.8320261437908496
# SVM rbf 7 auto: 0.7875816993464052
# SVM rbf 7 auto: 0.7751633986928104
# SVM rbf 7 auto: 0.8320261437908496
# SVM rbf 8 scale: 0.7875816993464052
# SVM rbf 8 scale: 0.7751633986928104
# SVM rbf 8 scale: 0.8209150326797385
# SVM rbf 8 auto: 0.7875816993464052
# SVM rbf 8 auto: 0.7751633986928104
# SVM rbf 8 auto: 0.8320261437908496
# SVM sigmoid 1 scale: 0.8104575163398693
# SVM sigmoid 1 scale: 0.8549019607843137
# SVM sigmoid 1 scale: 0.8320261437908496
# SVM sigmoid 1 auto: 0.7660130718954248
# SVM sigmoid 1 auto: 0.8549019607843137
# SVM sigmoid 1 auto: 0.8320261437908496
# SVM sigmoid 2 scale: 0.7542483660130719
# SVM sigmoid 2 scale: 0.8549019607843137
# SVM sigmoid 2 scale: 0.8209150326797385
# SVM sigmoid 2 auto: 0.8098039215686275
# SVM sigmoid 2 auto: 0.8549019607843137
# SVM sigmoid 2 auto: 0.8209150326797385
# SVM sigmoid 3 scale: 0.8209150326797385
# SVM sigmoid 3 scale: 0.8549019607843137
# SVM sigmoid 3 scale: 0.8431372549019607
# SVM sigmoid 3 auto: 0.7875816993464052
# SVM sigmoid 3 auto: 0.8437908496732026
# SVM sigmoid 3 auto: 0.8542483660130721
# SVM sigmoid 4 scale: 0.7431372549019608
# SVM sigmoid 4 scale: 0.8326797385620915
# SVM sigmoid 4 scale: 0.8437908496732026
# SVM sigmoid 4 auto: 0.7431372549019608
# SVM sigmoid 4 auto: 0.8326797385620915
# SVM sigmoid 4 auto: 0.8549019607843137
# SVM sigmoid 5 scale: 0.7875816993464052
# SVM sigmoid 5 scale: 0.8549019607843137
# SVM sigmoid 5 scale: 0.8104575163398693
# SVM sigmoid 5 auto: 0.7875816993464052
# SVM sigmoid 5 auto: 0.8437908496732026
# SVM sigmoid 5 auto: 0.8104575163398693
# SVM sigmoid 6 scale: 0.7875816993464052
# SVM sigmoid 6 scale: 0.8549019607843137
# SVM sigmoid 6 scale: 0.8215686274509805
# SVM sigmoid 6 auto: 0.7986928104575164
# SVM sigmoid 6 auto: 0.8326797385620915
# SVM sigmoid 6 auto: 0.8215686274509805
# SVM sigmoid 7 scale: 0.7764705882352941
# SVM sigmoid 7 scale: 0.8326797385620915
# SVM sigmoid 7 scale: 0.8437908496732026
# SVM sigmoid 7 auto: 0.7764705882352941
# SVM sigmoid 7 auto: 0.8215686274509805
# SVM sigmoid 7 auto: 0.8326797385620915
# SVM sigmoid 8 scale: 0.7764705882352941
# SVM sigmoid 8 scale: 0.7993464052287582
# SVM sigmoid 8 scale: 0.8437908496732026
# SVM sigmoid 8 auto: 0.765359477124183
# SVM sigmoid 8 auto: 0.7882352941176471
# SVM sigmoid 8 auto: 0.8437908496732026

# %%
# cool only

# %%
X = cool_only_df.iloc[:, :-1]
y = cool_only_df['label']

# %%
for i in range(1, 30):
    clf = KNeighborsClassifier(n_neighbors=i)
    scores = cross_val_score(clf, X, y, cv=5).mean()
    print(f'KNN {i}: {scores}')
# Out:
# KNN 1: 0.5657894736842105
# KNN 2: 0.5542105263157894
# KNN 3: 0.6157894736842106
# KNN 4: 0.6052631578947368
# KNN 5: 0.6873684210526316
# KNN 6: 0.6768421052631578
# KNN 7: 0.6763157894736842
# KNN 8: 0.6668421052631579
# KNN 9: 0.6768421052631578
# KNN 10: 0.6873684210526316
# KNN 11: 0.6868421052631579
# KNN 12: 0.6878947368421052
# KNN 13: 0.6973684210526316
# KNN 14: 0.6873684210526316
# KNN 15: 0.6768421052631578
# KNN 16: 0.6568421052631579
# KNN 17: 0.6568421052631579
# KNN 18: 0.6463157894736842
# KNN 19: 0.6468421052631579
# KNN 20: 0.6468421052631579
# KNN 21: 0.6473684210526316
# KNN 22: 0.6263157894736843
# KNN 23: 0.6268421052631579
# KNN 24: 0.6568421052631579
# KNN 25: 0.6473684210526316
# KNN 26: 0.5952631578947368
# KNN 27: 0.5952631578947368
# KNN 28: 0.6152631578947367
# KNN 29: 0.6257894736842105

# %%
for i in range(1, 30):
    clf = DecisionTreeClassifier(max_depth=i)
    scores = cross_val_score(clf, X, y, cv=5).mean()
    print(f'Decision Tree {i}: {scores}')
# Out:
# Decision Tree 1: 0.6457894736842105
# Decision Tree 2: 0.6147368421052631
# Decision Tree 3: 0.5747368421052632
# Decision Tree 4: 0.5747368421052632
# Decision Tree 5: 0.6147368421052632
# Decision Tree 6: 0.5447368421052632
# Decision Tree 7: 0.5352631578947369
# Decision Tree 8: 0.5863157894736842
# Decision Tree 9: 0.5347368421052632
# Decision Tree 10: 0.5357894736842106
# Decision Tree 11: 0.5963157894736841
# Decision Tree 12: 0.5747368421052632
# Decision Tree 13: 0.5242105263157895
# Decision Tree 14: 0.5557894736842106
# Decision Tree 15: 0.5042105263157894
# Decision Tree 16: 0.5447368421052632
# Decision Tree 17: 0.5747368421052632
# Decision Tree 18: 0.5342105263157895
# Decision Tree 19: 0.5347368421052632
# Decision Tree 20: 0.5452631578947369
# Decision Tree 21: 0.6157894736842106
# Decision Tree 22: 0.5763157894736842
# Decision Tree 23: 0.5457894736842105
# Decision Tree 24: 0.5652631578947369
# Decision Tree 25: 0.5552631578947368
# Decision Tree 26: 0.5868421052631578
# Decision Tree 27: 0.5763157894736842
# Decision Tree 28: 0.5752631578947368
# Decision Tree 29: 0.5242105263157895

# %%
# rf
n_estimators = range(1, 500, 10)
loss = ['gini', 'entropy']

# %%
for n in n_estimators:
    for l in loss:
        clf = RandomForestClassifier(n_estimators=n, criterion=l)
        scores = cross_val_score(clf, X, y, cv=5).mean()
        print(f'Random Forest {n} {l}: {scores}')
# Out:
# Random Forest 1 gini: 0.5242105263157895
# Random Forest 1 entropy: 0.5473684210526316
# Random Forest 11 gini: 0.6468421052631579
# Random Forest 11 entropy: 0.6473684210526316
# Random Forest 21 gini: 0.6663157894736843
# Random Forest 21 entropy: 0.6778947368421052
# Random Forest 31 gini: 0.6363157894736842
# Random Forest 31 entropy: 0.6563157894736842
# Random Forest 41 gini: 0.6763157894736842
# Random Forest 41 entropy: 0.6863157894736842
# Random Forest 51 gini: 0.7173684210526315
# Random Forest 51 entropy: 0.6768421052631579
# Random Forest 61 gini: 0.6768421052631579
# Random Forest 61 entropy: 0.6868421052631579
# Random Forest 71 gini: 0.6457894736842105
# Random Forest 71 entropy: 0.6468421052631579
# Random Forest 81 gini: 0.6963157894736842
# Random Forest 81 entropy: 0.6863157894736842
# Random Forest 91 gini: 0.6863157894736842
# Random Forest 91 entropy: 0.6668421052631579
# Random Forest 101 gini: 0.6763157894736842
# Random Forest 101 entropy: 0.6368421052631579
# Random Forest 111 gini: 0.6663157894736843
# Random Forest 111 entropy: 0.6773684210526316
# Random Forest 121 gini: 0.6868421052631579
# Random Forest 121 entropy: 0.6873684210526316
# Random Forest 131 gini: 0.6878947368421052
# Random Forest 131 entropy: 0.6968421052631578
# Random Forest 141 gini: 0.6763157894736841
# Random Forest 141 entropy: 0.6668421052631579
# Random Forest 151 gini: 0.6663157894736841
# Random Forest 151 entropy: 0.6768421052631579
# Random Forest 161 gini: 0.6663157894736841
# Random Forest 161 entropy: 0.6563157894736842
# Random Forest 171 gini: 0.6763157894736842
# Random Forest 171 entropy: 0.6763157894736842
# Random Forest 181 gini: 0.6463157894736842
# Random Forest 181 entropy: 0.6763157894736842
# Random Forest 191 gini: 0.6663157894736843
# Random Forest 191 entropy: 0.6463157894736842
# Random Forest 201 gini: 0.6763157894736842
# Random Forest 201 entropy: 0.6663157894736841
# Random Forest 211 gini: 0.6563157894736843
# Random Forest 211 entropy: 0.6873684210526315
# Random Forest 221 gini: 0.6763157894736842
# Random Forest 221 entropy: 0.6463157894736842
# Random Forest 231 gini: 0.6463157894736842
# Random Forest 231 entropy: 0.6563157894736842
# Random Forest 241 gini: 0.7068421052631578
# Random Forest 241 entropy: 0.6763157894736842
# Random Forest 251 gini: 0.6668421052631579
# Random Forest 251 entropy: 0.6863157894736842
# Random Forest 261 gini: 0.6768421052631579
# Random Forest 261 entropy: 0.6863157894736842
# Random Forest 271 gini: 0.6663157894736843
# Random Forest 271 entropy: 0.6563157894736842
# Random Forest 281 gini: 0.6668421052631579
# Random Forest 281 entropy: 0.6663157894736841
# Random Forest 291 gini: 0.6763157894736842
# Random Forest 291 entropy: 0.6763157894736842
# Random Forest 301 gini: 0.6563157894736842
# Random Forest 301 entropy: 0.6863157894736842
# Random Forest 311 gini: 0.6763157894736842
# Random Forest 311 entropy: 0.6768421052631579
# Random Forest 321 gini: 0.6663157894736841
# Random Forest 321 entropy: 0.6773684210526316
# Random Forest 331 gini: 0.6563157894736842
# Random Forest 331 entropy: 0.6863157894736842
# Random Forest 341 gini: 0.6663157894736843
# Random Forest 341 entropy: 0.6763157894736842
# Random Forest 351 gini: 0.6563157894736842
# Random Forest 351 entropy: 0.6768421052631578
# Random Forest 361 gini: 0.6963157894736842
# Random Forest 361 entropy: 0.6763157894736842
# Random Forest 371 gini: 0.6663157894736843
# Random Forest 371 entropy: 0.6663157894736843
# Random Forest 381 gini: 0.6663157894736843
# Random Forest 381 entropy: 0.6763157894736842
# Random Forest 391 gini: 0.6763157894736842
# Random Forest 391 entropy: 0.6663157894736841
# Random Forest 401 gini: 0.6563157894736843
# Random Forest 401 entropy: 0.6663157894736843
# Random Forest 411 gini: 0.6663157894736843
# Random Forest 411 entropy: 0.6868421052631579
# Random Forest 421 gini: 0.6663157894736843
# Random Forest 421 entropy: 0.6663157894736843
# Random Forest 431 gini: 0.6663157894736843
# Random Forest 431 entropy: 0.6663157894736843
# Random Forest 441 gini: 0.6563157894736842
# Random Forest 441 entropy: 0.6563157894736842
# Random Forest 451 gini: 0.6663157894736843
# Random Forest 451 entropy: 0.6663157894736841
# Random Forest 461 gini: 0.6663157894736841
# Random Forest 461 entropy: 0.6873684210526315
# Random Forest 471 gini: 0.6463157894736842
# Random Forest 471 entropy: 0.6663157894736843
# Random Forest 481 gini: 0.6763157894736842
# Random Forest 481 entropy: 0.6663157894736841
# Random Forest 491 gini: 0.6463157894736842
# Random Forest 491 entropy: 0.6763157894736842

# %%
kernel = ['linear', 'poly', 'rbf', 'sigmoid']
C = range(1, 9)
gamma = ['scale', 'auto']

# %%
for k in kernel:
    for c in C:
        for g in gamma:
            clf = SVC(kernel=k, C=c*10, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
            
            clf = SVC(kernel=k, C=c, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
            
            clf = SVC(kernel=k, C=c*.1, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
# Out:
# SVM linear 1 scale: 0.6273684210526316
# SVM linear 1 scale: 0.6157894736842106
# SVM linear 1 scale: 0.6363157894736842
# SVM linear 1 auto: 0.6273684210526316
# SVM linear 1 auto: 0.6157894736842106
# SVM linear 1 auto: 0.6363157894736842
# SVM linear 2 scale: 0.6073684210526316
# SVM linear 2 scale: 0.6363157894736842
# SVM linear 2 scale: 0.6463157894736842
# SVM linear 2 auto: 0.6073684210526316
# SVM linear 2 auto: 0.6363157894736842
# SVM linear 2 auto: 0.6463157894736842
# SVM linear 3 scale: 0.6273684210526316
# SVM linear 3 scale: 0.6163157894736843
# SVM linear 3 scale: 0.6563157894736842
# SVM linear 3 auto: 0.6273684210526316
# SVM linear 3 auto: 0.6163157894736843
# SVM linear 3 auto: 0.6563157894736842
# SVM linear 4 scale: 0.6173684210526316
# SVM linear 4 scale: 0.6268421052631579
# SVM linear 4 scale: 0.6363157894736842
# SVM linear 4 auto: 0.6173684210526316
# SVM linear 4 auto: 0.6268421052631579
# SVM linear 4 auto: 0.6363157894736842
# SVM linear 5 scale: 0.6173684210526316
# SVM linear 5 scale: 0.6268421052631579
# SVM linear 5 scale: 0.6363157894736842
# SVM linear 5 auto: 0.6173684210526316
# SVM linear 5 auto: 0.6268421052631579
# SVM linear 5 auto: 0.6363157894736842
# SVM linear 6 scale: 0.6173684210526316
# SVM linear 6 scale: 0.6268421052631579
# SVM linear 6 scale: 0.6363157894736842
# SVM linear 6 auto: 0.6173684210526316
# SVM linear 6 auto: 0.6268421052631579
# SVM linear 6 auto: 0.6363157894736842
# SVM linear 7 scale: 0.6173684210526316
# SVM linear 7 scale: 0.6368421052631579
# SVM linear 7 scale: 0.6363157894736842
# SVM linear 7 auto: 0.6173684210526316
# SVM linear 7 auto: 0.6368421052631579
# SVM linear 7 auto: 0.6363157894736842
# SVM linear 8 scale: 0.6173684210526316
# SVM linear 8 scale: 0.6373684210526316
# SVM linear 8 scale: 0.6463157894736842
# SVM linear 8 auto: 0.6173684210526316
# SVM linear 8 auto: 0.6373684210526316
# SVM linear 8 auto: 0.6463157894736842
# SVM poly 1 scale: 0.6163157894736843
# SVM poly 1 scale: 0.5863157894736842
# SVM poly 1 scale: 0.6073684210526316
# SVM poly 1 auto: 0.6063157894736844
# SVM poly 1 auto: 0.5963157894736841
# SVM poly 1 auto: 0.6073684210526316
# SVM poly 2 scale: 0.5847368421052632
# SVM poly 2 scale: 0.6063157894736841
# SVM poly 2 scale: 0.5868421052631578
# SVM poly 2 auto: 0.5947368421052632
# SVM poly 2 auto: 0.6163157894736843
# SVM poly 2 auto: 0.5868421052631578
# SVM poly 3 scale: 0.5947368421052632
# SVM poly 3 scale: 0.5863157894736842
# SVM poly 3 scale: 0.6178947368421053
# SVM poly 3 auto: 0.5947368421052632
# SVM poly 3 auto: 0.5963157894736841
# SVM poly 3 auto: 0.6078947368421053
# SVM poly 4 scale: 0.6152631578947368
# SVM poly 4 scale: 0.5957894736842105
# SVM poly 4 scale: 0.5763157894736842
# SVM poly 4 auto: 0.6152631578947368
# SVM poly 4 auto: 0.5857894736842105
# SVM poly 4 auto: 0.5963157894736841
# SVM poly 5 scale: 0.5952631578947368
# SVM poly 5 scale: 0.6163157894736843
# SVM poly 5 scale: 0.5657894736842105
# SVM poly 5 auto: 0.5952631578947368
# SVM poly 5 auto: 0.6063157894736844
# SVM poly 5 auto: 0.5657894736842105
# SVM poly 6 scale: 0.5952631578947368
# SVM poly 6 scale: 0.5957894736842106
# SVM poly 6 scale: 0.5857894736842105
# SVM poly 6 auto: 0.5852631578947368
# SVM poly 6 auto: 0.5957894736842106
# SVM poly 6 auto: 0.5757894736842105
# SVM poly 7 scale: 0.5752631578947368
# SVM poly 7 scale: 0.5957894736842106
# SVM poly 7 scale: 0.5868421052631578
# SVM poly 7 auto: 0.5452631578947369
# SVM poly 7 auto: 0.5957894736842106
# SVM poly 7 auto: 0.5968421052631578
# SVM poly 8 scale: 0.5457894736842106
# SVM poly 8 scale: 0.6157894736842106
# SVM poly 8 scale: 0.5763157894736842
# SVM poly 8 auto: 0.5457894736842105
# SVM poly 8 auto: 0.6057894736842105
# SVM poly 8 auto: 0.5763157894736842
# SVM rbf 1 scale: 0.6663157894736841
# SVM rbf 1 scale: 0.6973684210526316
# SVM rbf 1 scale: 0.5368421052631579
# SVM rbf 1 auto: 0.6563157894736842
# SVM rbf 1 auto: 0.6973684210526316
# SVM rbf 1 auto: 0.5368421052631579
# SVM rbf 2 scale: 0.6357894736842105
# SVM rbf 2 scale: 0.6873684210526315
# SVM rbf 2 scale: 0.6668421052631578
# SVM rbf 2 auto: 0.6357894736842105
# SVM rbf 2 auto: 0.6973684210526316
# SVM rbf 2 auto: 0.6668421052631578
# SVM rbf 3 scale: 0.6257894736842105
# SVM rbf 3 scale: 0.6873684210526316
# SVM rbf 3 scale: 0.6763157894736842
# SVM rbf 3 auto: 0.6157894736842106
# SVM rbf 3 auto: 0.6873684210526316
# SVM rbf 3 auto: 0.6763157894736842
# SVM rbf 4 scale: 0.6252631578947369
# SVM rbf 4 scale: 0.7178947368421053
# SVM rbf 4 scale: 0.6768421052631579
# SVM rbf 4 auto: 0.6252631578947369
# SVM rbf 4 auto: 0.7178947368421053
# SVM rbf 4 auto: 0.6768421052631579
# SVM rbf 5 scale: 0.6352631578947368
# SVM rbf 5 scale: 0.7278947368421053
# SVM rbf 5 scale: 0.6768421052631579
# SVM rbf 5 auto: 0.6452631578947368
# SVM rbf 5 auto: 0.7278947368421053
# SVM rbf 5 auto: 0.6768421052631579
# SVM rbf 6 scale: 0.6452631578947368
# SVM rbf 6 scale: 0.7178947368421053
# SVM rbf 6 scale: 0.6768421052631579
# SVM rbf 6 auto: 0.6352631578947368
# SVM rbf 6 auto: 0.7078947368421054
# SVM rbf 6 auto: 0.6668421052631579
# SVM rbf 7 scale: 0.6352631578947368
# SVM rbf 7 scale: 0.6873684210526315
# SVM rbf 7 scale: 0.6663157894736841
# SVM rbf 7 auto: 0.6452631578947368
# SVM rbf 7 auto: 0.6773684210526316
# SVM rbf 7 auto: 0.6663157894736841
# SVM rbf 8 scale: 0.6452631578947368
# SVM rbf 8 scale: 0.6973684210526316
# SVM rbf 8 scale: 0.6868421052631579
# SVM rbf 8 auto: 0.6352631578947368
# SVM rbf 8 auto: 0.6773684210526316
# SVM rbf 8 auto: 0.6868421052631579
# SVM sigmoid 1 scale: 0.5778947368421052
# SVM sigmoid 1 scale: 0.5557894736842106
# SVM sigmoid 1 scale: 0.6678947368421053
# SVM sigmoid 1 auto: 0.5878947368421052
# SVM sigmoid 1 auto: 0.5557894736842106
# SVM sigmoid 1 auto: 0.6778947368421052
# SVM sigmoid 2 scale: 0.6278947368421053
# SVM sigmoid 2 scale: 0.5468421052631578
# SVM sigmoid 2 scale: 0.6268421052631579
# SVM sigmoid 2 auto: 0.6378947368421052
# SVM sigmoid 2 auto: 0.5568421052631579
# SVM sigmoid 2 auto: 0.6368421052631579
# SVM sigmoid 3 scale: 0.6078947368421053
# SVM sigmoid 3 scale: 0.5368421052631579
# SVM sigmoid 3 scale: 0.6368421052631579
# SVM sigmoid 3 auto: 0.6178947368421053
# SVM sigmoid 3 auto: 0.5468421052631578
# SVM sigmoid 3 auto: 0.6368421052631579
# SVM sigmoid 4 scale: 0.5978947368421054
# SVM sigmoid 4 scale: 0.5368421052631579
# SVM sigmoid 4 scale: 0.6268421052631579
# SVM sigmoid 4 auto: 0.6078947368421053
# SVM sigmoid 4 auto: 0.5568421052631579
# SVM sigmoid 4 auto: 0.6368421052631579
# SVM sigmoid 5 scale: 0.6478947368421053
# SVM sigmoid 5 scale: 0.5568421052631579
# SVM sigmoid 5 scale: 0.5857894736842105
# SVM sigmoid 5 auto: 0.6278947368421053
# SVM sigmoid 5 auto: 0.5868421052631578
# SVM sigmoid 5 auto: 0.5957894736842105
# SVM sigmoid 6 scale: 0.6278947368421053
# SVM sigmoid 6 scale: 0.5668421052631579
# SVM sigmoid 6 scale: 0.5552631578947368
# SVM sigmoid 6 auto: 0.5868421052631578
# SVM sigmoid 6 auto: 0.5268421052631579
# SVM sigmoid 6 auto: 0.5552631578947368
# SVM sigmoid 7 scale: 0.6478947368421053
# SVM sigmoid 7 scale: 0.5678947368421052
# SVM sigmoid 7 scale: 0.5857894736842105
# SVM sigmoid 7 auto: 0.5957894736842106
# SVM sigmoid 7 auto: 0.5778947368421052
# SVM sigmoid 7 auto: 0.5857894736842105
# SVM sigmoid 8 scale: 0.6178947368421053
# SVM sigmoid 8 scale: 0.5978947368421054
# SVM sigmoid 8 scale: 0.5757894736842105
# SVM sigmoid 8 auto: 0.6273684210526316
# SVM sigmoid 8 auto: 0.5778947368421052
# SVM sigmoid 8 auto: 0.5657894736842105

# %%
# warm and cool

# %%
X = warm_cool_df.iloc[:, :-1]
y = warm_cool_df['label']

# %%
for i in range(1, 30):
    clf = KNeighborsClassifier(n_neighbors=i)
    scores = cross_val_score(clf, X, y, cv=5).mean()
    print(f'KNN {i}: {scores}')
# Out:
# KNN 1: 0.6019914651493599
# KNN 2: 0.5746799431009958
# KNN 3: 0.6337126600284495
# KNN 4: 0.6176386913229018
# KNN 5: 0.6603129445234709
# KNN 6: 0.655049786628734
# KNN 7: 0.7076813655761025
# KNN 8: 0.6916073968705547
# KNN 9: 0.6705547652916074
# KNN 10: 0.6815078236130867
# KNN 11: 0.67624466571835
# KNN 12: 0.707823613086771
# KNN 13: 0.6813655761024182
# KNN 14: 0.6863442389758179
# KNN 15: 0.6758179231863441
# KNN 16: 0.6970128022759602
# KNN 17: 0.6864864864864865
# KNN 18: 0.6920341394025604
# KNN 19: 0.6810810810810811
# KNN 20: 0.6759601706970128
# KNN 21: 0.6440967283072546
# KNN 22: 0.6549075391180654
# KNN 23: 0.6598862019914652
# KNN 24: 0.6543385490753911
# KNN 25: 0.6645803698435279
# KNN 26: 0.6651493598862019
# KNN 27: 0.6543385490753912
# KNN 28: 0.6544807965860597
# KNN 29: 0.6382645803698436

# %%
for i in range(1, 30):
    clf = DecisionTreeClassifier(max_depth=i)
    scores = cross_val_score(clf, X, y, cv=5).mean()
    print(f'Decision Tree {i}: {scores}')
# Out:
# Decision Tree 1: 0.4896159317211949
# Decision Tree 2: 0.6702702702702703
# Decision Tree 3: 0.6547652916073969
# Decision Tree 4: 0.6281650071123756
# Decision Tree 5: 0.6120910384068279
# Decision Tree 6: 0.6331436699857752
# Decision Tree 7: 0.6116642958748222
# Decision Tree 8: 0.6281650071123756
# Decision Tree 9: 0.6759601706970128
# Decision Tree 10: 0.6385490753911806
# Decision Tree 11: 0.6227596017069701
# Decision Tree 12: 0.6064011379800853
# Decision Tree 13: 0.6438122332859175
# Decision Tree 14: 0.6172119487908961
# Decision Tree 15: 0.6115220483641537
# Decision Tree 16: 0.6226173541963016
# Decision Tree 17: 0.6384068278805122
# Decision Tree 18: 0.5958748221906116
# Decision Tree 19: 0.665433854907539
# Decision Tree 20: 0.6280227596017071
# Decision Tree 21: 0.6172119487908961
# Decision Tree 22: 0.5748221906116642
# Decision Tree 23: 0.628022759601707
# Decision Tree 24: 0.6226173541963016
# Decision Tree 25: 0.6275960170697014
# Decision Tree 26: 0.6170697012802276
# Decision Tree 27: 0.5965860597439545
# Decision Tree 28: 0.6331436699857752
# Decision Tree 29: 0.5906116642958749

# %%
# rf
n_estimators = range(1, 500, 10)
loss = ['gini', 'entropy']

# %%
for n in n_estimators:
    for l in loss:
        clf = RandomForestClassifier(n_estimators=n, criterion=l)
        scores = cross_val_score(clf, X, y, cv=5).mean()
        print(f'Random Forest {n} {l}: {scores}')
# Out:
# Random Forest 1 gini: 0.5435277382645803
# Random Forest 1 entropy: 0.5539118065433855
# Random Forest 11 gini: 0.6652916073968705
# Random Forest 11 entropy: 0.6972972972972973
# Random Forest 21 gini: 0.6866287339971551
# Random Forest 21 entropy: 0.7132290184921765
# Random Forest 31 gini: 0.7028449502133712
# Random Forest 31 entropy: 0.6971550497866288
# Random Forest 41 gini: 0.6863442389758179
# Random Forest 41 entropy: 0.6867709815078237
# Random Forest 51 gini: 0.692176386913229
# Random Forest 51 entropy: 0.7025604551920341
# Random Forest 61 gini: 0.6651493598862019
# Random Forest 61 entropy: 0.7238975817923186
# Random Forest 71 gini: 0.6810810810810811
# Random Forest 71 entropy: 0.6975817923186345
# Random Forest 81 gini: 0.7076813655761024
# Random Forest 81 entropy: 0.7027027027027027
# Random Forest 91 gini: 0.6920341394025604
# Random Forest 91 entropy: 0.6918918918918918
# Random Forest 101 gini: 0.6810810810810811
# Random Forest 101 entropy: 0.7186344238975819
# Random Forest 111 gini: 0.7078236130867709
# Random Forest 111 entropy: 0.686628733997155
# Random Forest 121 gini: 0.6863442389758179
# Random Forest 121 entropy: 0.7024182076813655
# Random Forest 131 gini: 0.6921763869132291
# Random Forest 131 entropy: 0.707823613086771
# Random Forest 141 gini: 0.6918918918918918
# Random Forest 141 entropy: 0.7078236130867709
# Random Forest 151 gini: 0.6866287339971551
# Random Forest 151 entropy: 0.707823613086771
# Random Forest 161 gini: 0.7129445234708393
# Random Forest 161 entropy: 0.7079658605974395
# Random Forest 171 gini: 0.6918918918918919
# Random Forest 171 entropy: 0.6972972972972974
# Random Forest 181 gini: 0.681081081081081
# Random Forest 181 entropy: 0.6813655761024182
# Random Forest 191 gini: 0.6972972972972973
# Random Forest 191 entropy: 0.6971550497866287
# Random Forest 201 gini: 0.6971550497866288
# Random Forest 201 entropy: 0.6971550497866288
# Random Forest 211 gini: 0.7024182076813655
# Random Forest 211 entropy: 0.6917496443812233
# Random Forest 221 gini: 0.7024182076813656
# Random Forest 221 entropy: 0.6761024182076814
# Random Forest 231 gini: 0.6917496443812233
# Random Forest 231 entropy: 0.6972972972972973
# Random Forest 241 gini: 0.6974395448079659
# Random Forest 241 entropy: 0.6869132290184922
# Random Forest 251 gini: 0.6918918918918918
# Random Forest 251 entropy: 0.6974395448079658
# Random Forest 261 gini: 0.6971550497866287
# Random Forest 261 entropy: 0.7027027027027027
# Random Forest 271 gini: 0.6918918918918919
# Random Forest 271 entropy: 0.6921763869132291
# Random Forest 281 gini: 0.6652916073968707
# Random Forest 281 entropy: 0.686913229018492
# Random Forest 291 gini: 0.6815078236130867
# Random Forest 291 entropy: 0.6759601706970129
# Random Forest 301 gini: 0.6917496443812233
# Random Forest 301 entropy: 0.7130867709815079
# Random Forest 311 gini: 0.7076813655761024
# Random Forest 311 entropy: 0.7079658605974395
# Random Forest 321 gini: 0.6920341394025604
# Random Forest 321 entropy: 0.6974395448079658
# Random Forest 331 gini: 0.7027027027027027
# Random Forest 331 entropy: 0.692176386913229
# Random Forest 341 gini: 0.7025604551920341
# Random Forest 341 entropy: 0.7027027027027026
# Random Forest 351 gini: 0.6918918918918918
# Random Forest 351 entropy: 0.6972972972972973
# Random Forest 361 gini: 0.6867709815078237
# Random Forest 361 entropy: 0.7025604551920341
# Random Forest 371 gini: 0.7130867709815079
# Random Forest 371 entropy: 0.6917496443812233
# Random Forest 381 gini: 0.7027027027027027
# Random Forest 381 entropy: 0.7079658605974395
# Random Forest 391 gini: 0.6972972972972973
# Random Forest 391 entropy: 0.7025604551920341
# Random Forest 401 gini: 0.6864864864864865
# Random Forest 401 entropy: 0.6974395448079658
# Random Forest 411 gini: 0.6920341394025604
# Random Forest 411 entropy: 0.6972972972972973
# Random Forest 421 gini: 0.6972972972972973
# Random Forest 421 entropy: 0.7079658605974395
# Random Forest 431 gini: 0.6920341394025604
# Random Forest 431 entropy: 0.6972972972972973
# Random Forest 441 gini: 0.707823613086771
# Random Forest 441 entropy: 0.6920341394025604
# Random Forest 451 gini: 0.6971550497866288
# Random Forest 451 entropy: 0.6867709815078237
# Random Forest 461 gini: 0.6971550497866287
# Random Forest 461 entropy: 0.6920341394025604
# Random Forest 471 gini: 0.6866287339971551
# Random Forest 471 entropy: 0.6867709815078236
# Random Forest 481 gini: 0.6920341394025604
# Random Forest 481 entropy: 0.7025604551920341
# Random Forest 491 gini: 0.6971550497866287
# Random Forest 491 entropy: 0.6974395448079659

# %%
kernel = ['linear', 'poly', 'rbf', 'sigmoid']
C = range(1, 9)
gamma = ['scale', 'auto']

# %%
for k in kernel:
    for c in C:
        for g in gamma:
            clf = SVC(kernel=k, C=c*10, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
            
            clf = SVC(kernel=k, C=c, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
            
            clf = SVC(kernel=k, C=c*.1, gamma=g)
            scores = cross_val_score(clf, X, y, cv=5).mean()
            print(f'SVM {k} {c} {g}: {scores}')
# Out:
# SVM linear 1 scale: 0.6812233285917496
# SVM linear 1 scale: 0.6758179231863443
# SVM linear 1 scale: 0.6756756756756757
# SVM linear 1 auto: 0.6812233285917496
# SVM linear 1 auto: 0.6758179231863443
# SVM linear 1 auto: 0.6756756756756757
# SVM linear 2 scale: 0.6863442389758179
# SVM linear 2 scale: 0.6490753911806544
# SVM linear 2 scale: 0.670697012802276
# SVM linear 2 auto: 0.6863442389758179
# SVM linear 2 auto: 0.6490753911806544
# SVM linear 2 auto: 0.670697012802276
# SVM linear 3 scale: 0.6704125177809388
# SVM linear 3 scale: 0.6597439544807966
# SVM linear 3 scale: 0.6651493598862019
# SVM linear 3 auto: 0.6704125177809388
# SVM linear 3 auto: 0.6597439544807966
# SVM linear 3 auto: 0.6651493598862019
# SVM linear 4 scale: 0.6809388335704124
# SVM linear 4 scale: 0.6651493598862019
# SVM linear 4 scale: 0.6596017069701281
# SVM linear 4 auto: 0.6809388335704124
# SVM linear 4 auto: 0.6651493598862019
# SVM linear 4 auto: 0.6596017069701281
# SVM linear 5 scale: 0.6650071123755333
# SVM linear 5 scale: 0.6759601706970128
# SVM linear 5 scale: 0.664864864864865
# SVM linear 5 auto: 0.6650071123755333
# SVM linear 5 auto: 0.6759601706970128
# SVM linear 5 auto: 0.664864864864865
# SVM linear 6 scale: 0.6704125177809388
# SVM linear 6 scale: 0.6652916073968705
# SVM linear 6 scale: 0.681081081081081
# SVM linear 6 auto: 0.6704125177809388
# SVM linear 6 auto: 0.6652916073968705
# SVM linear 6 auto: 0.681081081081081
# SVM linear 7 scale: 0.6544807965860597
# SVM linear 7 scale: 0.6759601706970128
# SVM linear 7 scale: 0.681081081081081
# SVM linear 7 auto: 0.6544807965860597
# SVM linear 7 auto: 0.6759601706970128
# SVM linear 7 auto: 0.681081081081081
# SVM linear 8 scale: 0.6544807965860597
# SVM linear 8 scale: 0.6759601706970128
# SVM linear 8 scale: 0.6863442389758179
# SVM linear 8 auto: 0.6544807965860597
# SVM linear 8 auto: 0.6759601706970128
# SVM linear 8 auto: 0.6863442389758179
# SVM poly 1 scale: 0.6651493598862019
# SVM poly 1 scale: 0.5964438122332859
# SVM poly 1 scale: 0.42105263157894735
# SVM poly 1 auto: 0.6705547652916074
# SVM poly 1 auto: 0.6017069701280227
# SVM poly 1 auto: 0.40483641536273113
# SVM poly 2 scale: 0.6815078236130867
# SVM poly 2 scale: 0.6654338549075391
# SVM poly 2 scale: 0.4419630156472262
# SVM poly 2 auto: 0.6869132290184922
# SVM poly 2 auto: 0.670697012802276
# SVM poly 2 auto: 0.4419630156472262
# SVM poly 3 scale: 0.6705547652916073
# SVM poly 3 scale: 0.6600284495021337
# SVM poly 3 scale: 0.4312944523470839
# SVM poly 3 auto: 0.6652916073968705
# SVM poly 3 auto: 0.6600284495021337
# SVM poly 3 auto: 0.4365576102418208
# SVM poly 4 scale: 0.6547652916073969
# SVM poly 4 scale: 0.6546230440967283
# SVM poly 4 scale: 0.4526315789473684
# SVM poly 4 auto: 0.6440967283072546
# SVM poly 4 auto: 0.6546230440967283
# SVM poly 4 auto: 0.4578947368421053
# SVM poly 5 scale: 0.6278805120910385
# SVM poly 5 scale: 0.6598862019914652
# SVM poly 5 scale: 0.49502133712660024
# SVM poly 5 auto: 0.6386913229018492
# SVM poly 5 auto: 0.6651493598862019
# SVM poly 5 auto: 0.49487908961593174
# SVM poly 6 scale: 0.6172119487908961
# SVM poly 6 scale: 0.6812233285917497
# SVM poly 6 scale: 0.5216216216216216
# SVM poly 6 auto: 0.6172119487908961
# SVM poly 6 auto: 0.6759601706970129
# SVM poly 6 auto: 0.5216216216216216
# SVM poly 7 scale: 0.6174964438122333
# SVM poly 7 scale: 0.6813655761024182
# SVM poly 7 scale: 0.5268847795163585
# SVM poly 7 auto: 0.6229018492176387
# SVM poly 7 auto: 0.6759601706970129
# SVM poly 7 auto: 0.5268847795163585
# SVM poly 8 scale: 0.6017069701280228
# SVM poly 8 scale: 0.6756756756756757
# SVM poly 8 scale: 0.5536273115220485
# SVM poly 8 auto: 0.6017069701280228
# SVM poly 8 auto: 0.681081081081081
# SVM poly 8 auto: 0.5536273115220485
# SVM rbf 1 scale: 0.6974395448079659
# SVM rbf 1 scale: 0.6755334281650072
# SVM rbf 1 scale: 0.6065433854907539
# SVM rbf 1 auto: 0.6974395448079659
# SVM rbf 1 auto: 0.6702702702702703
# SVM rbf 1 auto: 0.6065433854907539
# SVM rbf 2 scale: 0.7079658605974395
# SVM rbf 2 scale: 0.6918918918918919
# SVM rbf 2 scale: 0.6385490753911807
# SVM rbf 2 auto: 0.7079658605974395
# SVM rbf 2 auto: 0.6918918918918919
# SVM rbf 2 auto: 0.6385490753911807
# SVM rbf 3 scale: 0.7025604551920341
# SVM rbf 3 scale: 0.6866287339971551
# SVM rbf 3 scale: 0.6705547652916074
# SVM rbf 3 auto: 0.7025604551920341
# SVM rbf 3 auto: 0.6918918918918919
# SVM rbf 3 auto: 0.6651493598862019
# SVM rbf 4 scale: 0.6866287339971551
# SVM rbf 4 scale: 0.6758179231863443
# SVM rbf 4 scale: 0.6759601706970128
# SVM rbf 4 auto: 0.6920341394025605
# SVM rbf 4 auto: 0.6758179231863443
# SVM rbf 4 auto: 0.6812233285917497
# SVM rbf 5 scale: 0.6759601706970128
# SVM rbf 5 scale: 0.6813655761024181
# SVM rbf 5 scale: 0.6651493598862019
# SVM rbf 5 auto: 0.6759601706970128
# SVM rbf 5 auto: 0.6813655761024181
# SVM rbf 5 auto: 0.6651493598862019
# SVM rbf 6 scale: 0.6654338549075391
# SVM rbf 6 scale: 0.7079658605974395
# SVM rbf 6 scale: 0.6758179231863443
# SVM rbf 6 auto: 0.6654338549075391
# SVM rbf 6 auto: 0.7079658605974395
# SVM rbf 6 auto: 0.6704125177809388
# SVM rbf 7 scale: 0.6708392603129446
# SVM rbf 7 scale: 0.6920341394025605
# SVM rbf 7 scale: 0.6704125177809388
# SVM rbf 7 auto: 0.6708392603129446
# SVM rbf 7 auto: 0.6920341394025605
# SVM rbf 7 auto: 0.6810810810810811
# SVM rbf 8 scale: 0.6601706970128023
# SVM rbf 8 scale: 0.6920341394025605
# SVM rbf 8 scale: 0.6810810810810811
# SVM rbf 8 auto: 0.6655761024182076
# SVM rbf 8 auto: 0.6920341394025605
# SVM rbf 8 auto: 0.6810810810810811
# SVM sigmoid 1 scale: 0.4837837837837838
# SVM sigmoid 1 scale: 0.606827880512091
# SVM sigmoid 1 scale: 0.6119487908961593
# SVM sigmoid 1 auto: 0.48890469416785204
# SVM sigmoid 1 auto: 0.6014224751066857
# SVM sigmoid 1 auto: 0.6226173541963016
# SVM sigmoid 2 scale: 0.4837837837837838
# SVM sigmoid 2 scale: 0.5635846372688478
# SVM sigmoid 2 scale: 0.6331436699857753
# SVM sigmoid 2 auto: 0.47837837837837843
# SVM sigmoid 2 auto: 0.5635846372688478
# SVM sigmoid 2 auto: 0.6331436699857753
# SVM sigmoid 3 scale: 0.4837837837837838
# SVM sigmoid 3 scale: 0.5264580369843529
# SVM sigmoid 3 scale: 0.6436699857752489
# SVM sigmoid 3 auto: 0.4890469416785206
# SVM sigmoid 3 auto: 0.5318634423897582
# SVM sigmoid 3 auto: 0.6384068278805122
# SVM sigmoid 4 scale: 0.4891891891891892
# SVM sigmoid 4 scale: 0.49985775248933145
# SVM sigmoid 4 scale: 0.6277382645803697
# SVM sigmoid 4 auto: 0.4891891891891892
# SVM sigmoid 4 auto: 0.5052631578947369
# SVM sigmoid 4 auto: 0.6223328591749644
# SVM sigmoid 5 scale: 0.47866287339971547
# SVM sigmoid 5 scale: 0.4947368421052632
# SVM sigmoid 5 scale: 0.6170697012802275
# SVM sigmoid 5 auto: 0.4732574679943101
# SVM sigmoid 5 auto: 0.5054054054054055
# SVM sigmoid 5 auto: 0.6278805120910383
# SVM sigmoid 6 scale: 0.478520625889047
# SVM sigmoid 6 scale: 0.4678520625889047
# SVM sigmoid 6 scale: 0.6065433854907539
# SVM sigmoid 6 auto: 0.4731152204836415
# SVM sigmoid 6 auto: 0.4625889046941679
# SVM sigmoid 6 auto: 0.6065433854907539
# SVM sigmoid 7 scale: 0.47297297297297297
# SVM sigmoid 7 scale: 0.4625889046941678
# SVM sigmoid 7 scale: 0.6332859174964438
# SVM sigmoid 7 auto: 0.4675675675675676
# SVM sigmoid 7 auto: 0.47325746799431007
# SVM sigmoid 7 auto: 0.6172119487908961
# SVM sigmoid 8 scale: 0.46244665718349925
# SVM sigmoid 8 scale: 0.47283072546230437
# SVM sigmoid 8 scale: 0.5961593172119488
# SVM sigmoid 8 auto: 0.4570412517780939
# SVM sigmoid 8 auto: 0.47283072546230437
# SVM sigmoid 8 auto: 0.6014224751066857
